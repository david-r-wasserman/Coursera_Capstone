# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from json import JSONDecodeError

import requests # library to handle requests

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you don't have the folium package
import folium # map rendering library

import math
import random

# %%
#To execute this notebook, you will need a verified Foursquare developer account
CLIENT_ID = 'fill in your Foursquare ID here' 
CLIENT_SECRET = 'fill in your Foursquare Secret here'
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# Our region of study will be a square, 25 kilometers by 25 kilometers, centered at 34.052200° N, 118.243700° W. These coordinates were obtained by searching Google for "los angeles lat/lon".
#
# We will use a spherical earth approximation to compute the latitudes and longitudes of the boundaries of this square, and the latitudes and longitudes of the boundaries of random points within this square. According to this approximation, one degree of latitude is 10<sup>7</sup>/90 meters, and one degree of longitude is cos(latitude)\*10<sup>7</sup>/90 meters.

# %%
la_lat, la_lon = (34.052200, -118.243700)
square_half_side = 12500 #meters

# %%
def north_east_of_la(north, east):
    '''Compute the latitude and longitude of a point in our
    study area, given its distance north/south and east/west
    of the center point
    
    Inputs:
        north: float; distance north of center point, in meters. 
            Use negative for points south of the center.
        east: float; distance east of center point, in meters. 
            Use negative for points west of the center.
            
    Returns: tuple (latitude, longitude), in degrees
    '''
    lat = la_lat + north*90/10**7
    lon = la_lon + east*90/(10**7*math.cos(lat*3.14159265359/180))
    return (lat, lon)

# %%
nw_corner = north_east_of_la(square_half_side, -square_half_side)
ne_corner = north_east_of_la(square_half_side, square_half_side)
sw_corner = north_east_of_la(-square_half_side, -square_half_side)
se_corner = north_east_of_la(-square_half_side, square_half_side)

# %%
map_of_study = folium.Map(location=[la_lat, la_lon], zoom_start=11)
folium.PolyLine(
    [nw_corner, ne_corner, se_corner, sw_corner, nw_corner]
    ).add_to(map_of_study)
map_of_study
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Let's create a function to query Foursquare for venues

# %%
def get_nearby_venues(x, y, radius=500, limit=100):
    '''
    Query Foursquare for venues near a particular point within the 
    study area, and return the IDs and categories of the venues. 
    Note that if limit > 100, Foursquare will return at most 100 venues.
    
    Inputs: 
        x: (float) x coordinate of the query point, in meters east 
            of the study center point
        y: (float) y coordinate of the query point, in meters north 
            of the study center point
        radius: (float) query radius, in meters
        limit: (int) maximum number of results to return
        
    Returns: a Series with venue IDs as the index and venue
        categories as the values
    '''
        
    (lat, lon) = north_east_of_la(y, x)
    venues_list=[]
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat,
            lon,
            radius, 
            limit)
    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    nearby_venues = pd.Series()
        
    # include only relevant information for each nearby venue
    for v in results:
        nearby_venues.loc[v['venue']['id']] = v['venue']['categories'][0]['name']
        
    return(nearby_venues)

# %% [markdown]
# We test `get_nearby_venues` at 50 random points within the study area:

# %%
for i in range(50):
    nv = get_nearby_venues(random.uniform(-square_half_side, square_half_side), 
                           random.uniform(-square_half_side, square_half_side), 
                           radius=1000, limit=150)
    print(len(nv))
# Out:
# 71
# 10
# 17
# 42
# 49
# 60
# 13
# 26
# 62
# 32
# 43
# 29
# 56
# 13
# 13
# 37
# 36
# 12
# 45
# 20
# 23
# 40
# 6
# 52
# 23
# 77
# 18
# 100
# 28
# 100
# 14
# 21
# 24
# 57
# 84
# 100
# 67
# 52
# 16
# 37
# 11
# 15
# 74
# 13
# 30
# 28
# 24
# 39
# 57
# 48

# %% [markdown]
# We see that several times, Foursquare returned 100 venues. Most likely, this means there were *n* > 100 venues within the query radius. We know that Foursquare is limited to returning 100 venues, but we don't know how Foursquare chooses 100 out of the _n_ venues. Its selection rule may cause an unknown bias. Therefore, when a query returns 100 venues, we do not use these results. However, if we  simply ignore these results, we are undersampling areas with a high density of venues. To avoid this problem, whenever a query returns 100 venues, we replace it with four more queries with half the radius. These four queries cover the same total area as the original query.

# %%
def get_nearby_venues_unbiased(x, y, radius=1000):
    '''
    Query Foursquare for venues near a particular point within the 
    study area, and return the IDs and categories of the venues. 
    Note that Foursquare will return at most 100 venues. 
    
    To ensure that Foursquare does not bias the results with
    unknown selection rules, we ignore the results of queries
    that return 100 venues. Instead, we execute queries for 
    four nearby points, using a radius half as large.
    
    Inputs: 
        x: (float) x coordinate of the query point, in meters east 
            of the study center point
        y: (float) y coordinate of the query point, in meters north 
            of the study center point
        radius: (float) query radius, in meters
        
    Returns: a DataFrame with a row for each venue found, with
        columns 'id' and 'category'
    '''
        
    limit = 100
    (lat, lon) = north_east_of_la(y, x)
    venues_list=[]
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat,
            lon,
            radius, 
            limit)
    # make the GET request
    json_received = None
    results = []
    try:
        json_received = requests.get(url).json()
    except JSONDecodeError:
        print('query failed')
    if json_received is not None:
        try:
            results = json_received["response"]['groups'][0]['items']
        except JSONDecodeError:
            print(json_received)
                
    if len(results) < limit:
        nearby_venues = pd.DataFrame(columns=['id', 'category'])
        
        # include only relevant information for each nearby venue
        for v in results:
            nearby_venues = nearby_venues.append(
                {'id': v['venue']['id'],
                 'category': v['venue']['categories'][0]['name']
                }, ignore_index=True)        
        print(len(nearby_venues))
    else:
        quadrants = [get_nearby_venues_unbiased(x + i*radius/2, y + j*radius/2, radius/2)
                     for i in [-1, 1] for j in [-1, 1]
                    ]
        nearby_venues = (pd.concat(quadrants, axis=0, ignore_index=True)
                         .drop_duplicates(subset=['id'], keep='first')
                        )
    
    return(nearby_venues)

# %% [markdown]
# We call `get_nearby_venues_unbiased` repeatedly at random locations until we have at least 10,000 distinct venues. We use `drop_duplicates` to ensure they are distinct.

# %%
#Collect required number of venues
venues_to_find = 10000
radius = 1000

#Query centers lie within a smaller square, so that the query
#circle stays within the study area
query_square_half_side = square_half_side - radius

venues = pd.DataFrame(columns=['id', 'category'])
centers_chosen = 0
while len(venues) < venues_to_find:
    random_x = random.uniform(-query_square_half_side,
                              query_square_half_side)
    random_y = random.uniform(-query_square_half_side,
                              query_square_half_side)
    centers_chosen += 1
    new_venues = get_nearby_venues_unbiased(random_x, random_y, radius)
    venues = (venues.append(new_venues, ignore_index=True, sort=False)
              .drop_duplicates(subset=['id'], keep='first')
             )
    print((centers_chosen, len(new_venues), len(venues)))
# Out:
# 5
# 13
# 89
# 14
# (1, 121, 121)
# 65
# (2, 65, 186)
# 21
# (3, 21, 207)
# 13
# (4, 13, 220)
# 98
# (5, 98, 318)
# 12
# 67
# 30
# 19
# 27
# 29
# 45
# (6, 229, 547)
# 26
# (7, 26, 573)
# 15
# (8, 15, 588)
# 50
# (9, 50, 634)
# 69
# (10, 69, 703)
# 99
# (11, 99, 802)
# 17
# (12, 17, 819)
# 12
# (13, 12, 828)
# 16
# (14, 16, 844)
# 21
# (15, 21, 865)
# 23
# (16, 23, 888)
# 24
# (17, 24, 912)
# 52
# (18, 52, 964)
# 56
# (19, 56, 1020)
# 59
# (20, 59, 1079)
# 9
# (21, 9, 1088)
# 66
# (22, 66, 1142)
# 13
# (23, 13, 1155)
# 31
# (24, 31, 1186)
# 36
# (25, 36, 1222)
# 43
# (26, 43, 1265)
# 59
# (27, 59, 1318)
# 22
# (28, 22, 1335)
# 85
# (29, 85, 1344)
# 72
# (30, 72, 1416)
# 42
# (31, 42, 1446)
# 43
# (32, 43, 1489)
# 16
# (33, 16, 1505)
# 38
# (34, 38, 1529)
# 24
# (35, 24, 1553)
# 33
# 11
# 1
# 95
# 11
# 4
# 47
# (36, 202, 1667)
# 27
# (37, 27, 1694)
# 38
# 29
# 54
# 44
# (38, 165, 1859)
# 98
# (39, 98, 1923)
# 18
# (40, 18, 1941)
# 58
# 61
# 12
# 32
# (41, 163, 2104)
# 14
# (42, 14, 2111)
# 60
# (43, 60, 2171)
# 84
# (44, 84, 2254)
# 16
# (45, 16, 2261)
# 16
# (46, 16, 2277)
# 59
# 49
# 3
# 10
# (47, 121, 2398)
# 16
# (48, 16, 2413)
# 46
# (49, 46, 2459)
# 32
# (50, 32, 2491)
# 14
# 51
# 1
# 53
# 29
# 14
# 31
# (51, 193, 2572)
# 11
# 11
# 19
# 25
# 19
# 20
# 43
# (52, 148, 2616)
# 33
# (53, 33, 2648)
# 24
# (54, 24, 2668)
# 23
# (55, 23, 2680)
# 35
# (56, 35, 2701)
# 25
# (57, 25, 2726)
# 17
# (58, 17, 2742)
# 45
# (59, 45, 2748)
# 32
# (60, 32, 2771)
# 13
# (61, 13, 2772)
# 9
# (62, 9, 2777)
# 15
# 14
# 48
# 21
# (63, 98, 2846)
# 11
# (64, 11, 2857)
# 26
# (65, 26, 2864)
# 15
# (66, 15, 2875)
# 37
# (67, 37, 2893)
# 8
# (68, 8, 2901)
# 7
# 28
# 59
# 3
# 42
# 25
# 29
# (69, 193, 2963)
# 11
# 65
# 20
# 74
# (70, 170, 2981)
# 44
# (71, 44, 3010)
# 51
# (72, 51, 3016)
# 28
# (73, 28, 3022)
# 21
# (74, 21, 3042)
# 22
# (75, 22, 3064)
# 68
# (76, 68, 3132)
# 17
# (77, 17, 3148)
# 19
# (78, 19, 3166)
# 17
# (79, 17, 3183)
# 21
# (80, 21, 3200)
# 27
# 41
# 51
# 24
# 49
# 11
# 35
# 7
# 88
# 35
# (81, 368, 3516)
# 30
# (82, 30, 3546)
# 56
# (83, 56, 3602)
# 11
# (84, 11, 3613)
# 50
# (85, 50, 3663)
# 22
# (86, 22, 3663)
# 23
# (87, 23, 3671)
# 53
# 52
# 27
# 35
# 19
# 59
# 51
# (88, 296, 3877)
# 13
# (89, 13, 3884)
# 29
# (90, 29, 3910)
# 17
# (91, 17, 3927)
# 15
# (92, 15, 3937)
# 20
# (93, 20, 3954)
# 30
# (94, 30, 3959)
# 24
# (95, 24, 3966)
# 19
# (96, 19, 3969)
# 96
# (97, 96, 4034)
# 33
# (98, 33, 4057)
# 21
# (99, 21, 4078)
# 28
# (100, 28, 4102)
# 69
# (101, 69, 4146)
# 38
# (102, 38, 4177)
# 43
# (103, 43, 4218)
# 71
# (104, 71, 4289)
# 25
# (105, 25, 4298)
# 28
# (106, 28, 4314)
# 71
# (107, 71, 4371)
# 14
# (108, 14, 4372)
# 42
# 90
# 5
# 59
# (109, 196, 4479)
# 31
# (110, 31, 4479)
# 37
# (111, 37, 4496)
# 72
# (112, 72, 4541)
# 6
# (113, 6, 4541)
# 23
# (114, 23, 4546)
# 10
# (115, 10, 4555)
# 37
# (116, 37, 4592)
# 37
# (117, 37, 4614)
# 18
# (118, 18, 4617)
# 20
# (119, 20, 4627)
# 58
# (120, 58, 4672)
# 36
# (121, 36, 4700)
# 86
# (122, 86, 4705)
# 57
# (123, 57, 4753)
# 35
# (124, 35, 4788)
# 96
# (125, 96, 4842)
# 43
# (126, 43, 4844)
# 36
# (127, 36, 4850)
# 29
# 23
# 50
# 0
# 25
# 33
# 64
# (128, 224, 4967)
# 46
# 41
# 12
# 24
# (129, 123, 5055)
# 45
# (130, 45, 5090)
# 51
# (131, 51, 5124)
# 40
# (132, 40, 5141)
# 14
# (133, 14, 5146)
# 24
# (134, 24, 5147)
# 24
# (135, 24, 5148)
# 27
# (136, 27, 5159)
# 65
# (137, 65, 5224)
# 23
# (138, 23, 5232)
# 25
# (139, 25, 5257)
# 72
# (140, 72, 5306)
# 49
# (141, 49, 5344)
# 99
# (142, 99, 5443)
# 55
# (143, 55, 5462)
# 35
# (144, 35, 5479)
# 32
# (145, 32, 5488)
# 7
# (146, 7, 5495)
# 33
# (147, 33, 5519)
# 64
# (148, 64, 5522)
# 61
# (149, 61, 5583)
# 40
# (150, 40, 5619)
# 31
# (151, 31, 5624)
# 65
# (152, 65, 5665)
# 16
# (153, 16, 5673)
# 17
# (154, 17, 5674)
# 74
# (155, 74, 5692)
# 40
# (156, 40, 5719)
# 62
# (157, 62, 5726)
# 83
# (158, 83, 5726)
# 13
# (159, 13, 5726)
# 21
# (160, 21, 5729)
# 34
# (161, 34, 5741)
# 29
# (162, 29, 5759)
# 45
# 41
# 18
# 15
# (163, 119, 5860)
# 28
# (164, 28, 5886)
# 37
# (165, 37, 5903)
# 30
# (166, 30, 5933)
# 19
# (167, 19, 5949)
# 73
# (168, 73, 6015)
# 16
# (169, 16, 6022)
# 65
# (170, 65, 6022)
# 14
# (171, 14, 6032)
# 28
# (172, 28, 6041)
# 20
# 40
# 4
# 41
# (173, 105, 6064)
# 70
# (174, 70, 6089)
# 68
# (175, 68, 6146)
# 18
# (176, 18, 6158)
# 30
# (177, 30, 6161)
# 26
# (178, 26, 6184)
# 49
# (179, 49, 6194)
# 37
# (180, 37, 6220)
# 38
# (181, 38, 6234)
# 50
# (182, 50, 6281)
# 18
# (183, 18, 6283)
# 18
# (184, 18, 6286)
# 65
# (185, 65, 6289)
# 34
# (186, 34, 6317)
# 23
# (187, 23, 6326)
# 85
# (188, 85, 6379)
# 22
# (189, 22, 6379)
# 15
# 12
# 38
# 34
# (190, 99, 6392)
# 12
# (191, 12, 6395)
# 15
# (192, 15, 6399)
# 50
# (193, 50, 6414)
# 6
# (194, 6, 6416)
# 11
# (195, 11, 6426)
# 26
# (196, 26, 6436)
# 36
# (197, 36, 6449)
# 43
# (198, 43, 6451)
# 20
# (199, 20, 6451)
# 7
# (200, 7, 6457)
# 26
# (201, 26, 6457)
# 86
# (202, 86, 6485)
# 56
# (203, 56, 6485)
# 21
# (204, 21, 6490)
# 41
# (205, 41, 6508)
# 45
# (206, 45, 6523)
# 33
# (207, 33, 6537)
# 64
# (208, 64, 6578)
# 32
# (209, 32, 6580)
# 20
# (210, 20, 6588)
# 19
# (211, 19, 6594)
# 31
# (212, 31, 6595)
# 29
# 99
# 7
# 41
# (213, 176, 6595)
# 31
# (214, 31, 6595)
# 78
# (215, 78, 6673)
# 22
# (216, 22, 6673)
# 17
# (217, 17, 6678)
# 29
# (218, 29, 6698)
# 22
# 41
# 8
# 32
# 19
# 37
# 16
# (219, 175, 6845)
# 4
# (220, 4, 6849)
# 33
# 25
# 59
# 14
# 16
# 78
# 11
# 6
# 2
# 84
# (221, 328, 6979)
# 43
# (222, 43, 7005)
# 25
# (223, 25, 7017)
# 37
# (224, 37, 7020)
# 99
# (225, 99, 7087)
# 87
# (226, 87, 7095)
# 95
# (227, 95, 7190)
# 40
# 30
# 43
# 25
# 47
# 19
# 16
# (228, 220, 7200)
# 21
# (229, 21, 7201)
# 26
# 85
# 20
# 15
# (230, 146, 7340)
# 20
# (231, 20, 7340)
# 60
# (232, 60, 7394)
# 26
# (233, 26, 7397)
# 69
# (234, 69, 7466)
# 36
# (235, 36, 7472)
# 38
# (236, 38, 7509)
# 69
# (237, 69, 7527)
# 12
# (238, 12, 7539)
# 71
# (239, 71, 7563)
# 59
# (240, 59, 7564)
# 22
# (241, 22, 7564)
# 24
# (242, 24, 7575)
# 38
# (243, 38, 7582)
# 24
# (244, 24, 7587)
# 14
# (245, 14, 7595)
# 77
# (246, 77, 7620)
# 59
# 74
# 44
# 24
# (247, 201, 7735)
# 16
# (248, 16, 7737)
# 11
# 42
# 33
# 58
# (249, 144, 7814)
# 29
# (250, 29, 7830)
# 14
# (251, 14, 7838)
# 67
# (252, 67, 7846)
# 10
# (253, 10, 7854)
# 75
# (254, 75, 7899)
# 10
# (255, 10, 7902)
# 19
# (256, 19, 7912)
# 26
# (257, 26, 7920)
# 45
# (258, 45, 7922)
# 33
# 41
# 19
# 12
# 60
# 18
# 17
# 71
# 16
# 49
# (259, 336, 8037)
# 23
# (260, 23, 8048)
# 35
# (261, 35, 8051)
# 17
# (262, 17, 8066)
# 95
# (263, 95, 8131)
# 6
# (264, 6, 8134)
# 74
# 30
# 19
# 3
# (265, 126, 8199)
# 65
# (266, 65, 8200)
# 71
# (267, 71, 8271)
# 13
# (268, 13, 8271)
# 57
# (269, 57, 8294)
# 37
# 26
# 33
# 32
# (270, 128, 8320)
# 45
# (271, 45, 8341)
# 52
# (272, 52, 8368)
# 38
# 40
# 42
# 8
# 46
# 32
# 0
# 30
# 24
# 25
# (273, 285, 8384)
# 22
# (274, 22, 8391)
# 59
# (275, 59, 8394)
# 9
# (276, 9, 8403)
# 22
# (277, 22, 8403)
# 24
# (278, 24, 8403)
# 13
# (279, 13, 8406)
# 84
# (280, 84, 8456)
# 27
# 40
# 8
# 43
# 50
# 10
# 62
# 27
# 32
# 37
# 11
# 62
# 6
# (281, 415, 8478)
# 34
# (282, 34, 8482)
# 9
# (283, 9, 8482)
# 21
# (284, 21, 8483)
# 48
# (285, 48, 8495)
# 26
# (286, 26, 8497)
# 39
# (287, 39, 8509)
# 76
# (288, 76, 8522)
# 33
# (289, 33, 8528)
# 82
# (290, 82, 8586)
# 87
# (291, 87, 8618)
# 8
# (292, 8, 8620)
# 23
# 29
# 73
# 27
# (293, 152, 8661)
# 15
# (294, 15, 8664)
# 63
# (295, 63, 8669)
# 90
# (296, 90, 8675)
# 21
# 46
# 18
# 36
# (297, 121, 8677)
# 39
# 60
# 42
# 30
# (298, 171, 8680)
# 68
# (299, 68, 8708)
# 25
# 58
# 32
# 45
# (300, 160, 8760)
# 29
# (301, 29, 8764)
# 20
# 20
# 23
# 17
# (302, 80, 8786)
# 31
# (303, 31, 8787)
# 43
# (304, 43, 8803)
# 23
# (305, 23, 8809)
# 23
# (306, 23, 8809)
# 20
# (307, 20, 8811)
# 36
# (308, 36, 8838)
# 29
# 14
# 80
# 1
# (309, 124, 8851)
# 45
# (310, 45, 8868)
# 58
# (311, 58, 8868)
# 21
# (312, 21, 8870)
# 38
# 30
# 70
# 4
# (313, 142, 8888)
# 12
# 61
# 24
# 74
# (314, 171, 8917)
# 46
# 5
# 87
# 16
# (315, 154, 8952)
# 84
# (316, 84, 8955)
# 45
# (317, 45, 8959)
# 23
# (318, 23, 8959)
# 69
# (319, 69, 8964)
# 72
# (320, 72, 8992)
# 52
# (321, 52, 8992)
# 15
# (322, 15, 9001)
# 86
# (323, 86, 9016)
# 44
# (324, 44, 9019)
# 22
# (325, 22, 9038)
# 80
# (326, 80, 9060)
# 91
# (327, 91, 9097)
# 4
# (328, 4, 9097)
# 60
# (329, 60, 9152)
# 22
# (330, 22, 9152)
# 46
# (331, 46, 9163)
# 68
# (332, 68, 9163)
# 64
# (333, 64, 9174)
# 22
# (334, 22, 9177)
# 32
# (335, 32, 9178)
# 60
# (336, 60, 9181)
# 21
# (337, 21, 9183)
# 37
# (338, 37, 9184)
# 30
# (339, 30, 9185)
# 44
# (340, 44, 9202)
# 27
# (341, 27, 9209)
# 31
# (342, 31, 9215)
# 24
# (343, 24, 9224)
# 12
# (344, 12, 9227)
# 68
# 41
# 25
# 54
# (345, 188, 9342)
# 33
# (346, 33, 9356)
# 64
# 69
# 3
# 5
# (347, 141, 9377)
# 61
# (348, 61, 9377)
# 28
# (349, 28, 9388)
# 10
# (350, 10, 9389)
# 34
# (351, 34, 9396)
# 40
# (352, 40, 9397)
# 28
# (353, 28, 9399)
# 50
# (354, 50, 9424)
# 37
# (355, 37, 9429)
# 39
# (356, 39, 9441)
# 56
# (357, 56, 9449)
# 72
# (358, 72, 9450)
# 74
# (359, 74, 9452)
# 22
# (360, 22, 9459)
# 49
# (361, 49, 9472)
# 43
# (362, 43, 9472)
# 25
# (363, 25, 9476)
# 27
# (364, 27, 9483)
# 44
# (365, 44, 9483)
# 21
# (366, 21, 9484)
# 19
# 28
# 29
# 57
# (367, 133, 9506)
# 25
# (368, 25, 9510)
# 63
# (369, 63, 9517)
# 50
# (370, 50, 9521)
# 91
# (371, 91, 9595)
# 12
# (372, 12, 9595)
# 46
# (373, 46, 9596)
# 54
# (374, 54, 9596)
# 62
# (375, 62, 9596)
# 16
# 23
# 57
# 41
# (376, 137, 9625)
# 17
# (377, 17, 9634)
# 21
# (378, 21, 9635)
# 20
# (379, 20, 9647)
# 8
# (380, 8, 9654)
# 15
# (381, 15, 9668)
# 35
# (382, 35, 9672)
# 64
# (383, 64, 9686)
# 25
# (384, 25, 9686)
# 25
# (385, 25, 9690)
# 31
# (386, 31, 9694)
# 47
# 14
# 14
# 36
# (387, 111, 9716)
# 81
# (388, 81, 9729)
# 24
# (389, 24, 9739)
# 17
# (390, 17, 9741)
# 25
# 9
# 34
# 64
# (391, 132, 9814)
# 48
# (392, 48, 9816)
# 10
# (393, 10, 9816)
# 92
# (394, 92, 9851)
# 24
# (395, 24, 9851)
# 60
# (396, 60, 9860)
# 27
# (397, 27, 9860)
# 41
# (398, 41, 9860)
# 41
# (399, 41, 9871)
# 26
# 6
# 51
# 67
# (400, 150, 9904)
# 9
# (401, 9, 9904)
# 30
# (402, 30, 9913)
# 42
# (403, 42, 9920)
# 21
# (404, 21, 9920)
# 58
# (405, 58, 9920)
# 62
# (406, 62, 9926)
# 18
# 78
# 16
# 69
# (407, 181, 9930)
# 17
# (408, 17, 9930)
# 24
# (409, 24, 9930)
# 33
# (410, 33, 9930)
# 97
# (411, 97, 9944)
# 19
# (412, 19, 9945)
# 5
# (413, 5, 9946)
# 88
# (414, 88, 9975)
# 10
# 84
# 42
# 6
# (415, 142, 9995)
# 22
# (416, 22, 10000)

# %%
##Save venues to a file
venues.to_csv('venues.csv')

# %%
venues.describe()
# Out:
#                               id            category
# count                      10000               10000
# unique                     10000                 454
# top     4c27dc1de19720a1f720f758  Mexican Restaurant
# freq                           1                 455

# %% [markdown]
# We have found a total of 10,000 venues. It will be useful to know how many are in each category:

# %%
categories = venues['category'].value_counts()

#Save category counts to a file
categories.to_csv('categories.csv')

# %%
venues = venues.reset_index()

# %% [markdown]
# In the cell below, for each of these 10,000 venues, we query Foursquare for its "next venues," which means the most common venues that a user checks in at after checking in at this venue. This takes about two hours.
#
# Occasionally, while the cell below is executing, Foursquare fails to return a valid result. In this case, the code below will print the JSON and continue. Allow the cell to execute until it finishes. Then replace `for i in venues.index:` with `for i in venues[pd.isna(venues['num next'])].index:` and re-execute the cell. This will repeat the queries that were not successful.

# %%
#for i in venues.index:
    
for i in venues[pd.isna(venues['num next'])].index:

    venue_id = venues.loc[i, 'id']
    url = 'https://api.foursquare.com/v2/venues/{}/nextvenues?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    json_received = None
    try:
        json_received = requests.get(url).json()
    except JSONDecodeError:
        print(i)
        print('query failed')
    if json_received is not None:
        try:
            num_next_venues = json_received['response']['nextVenues']['count']
            next_venues = json_received['response']['nextVenues']['items']
            venues.loc[i, 'num next'] = num_next_venues
            for j in range(num_next_venues):
                venues.loc[i, 'next' + str(j + 1)] = next_venues[j]['categories'][0]['name']
        except KeyError:
            print(i)
            print(json_received)
        
    if i%100 == 0:
        print(i)
        #Save progress to a file so we can recover from a crash
        venues.to_csv('venuesWithNext.csv')

# %%
venues.describe(include='all')
# Out:
#                index                        id            category  \
# count   10000.000000                     10000               10000
# unique           NaN                     10000                 454
# top              NaN  4c27dc1de19720a1f720f758  Mexican Restaurant
# freq             NaN                         1                 455
# mean     4999.504800                       NaN                 NaN
# std      2886.904001                       NaN                 NaN
# min         0.000000                       NaN                 NaN
# 25%      2499.750000                       NaN                 NaN
# 50%      4999.500000                       NaN                 NaN
# 75%      7499.250000                       NaN                 NaN
# max     10015.000000                       NaN                 NaN
#
#             num next        next1        next2        next3        next4  \
# count   10000.000000         4955         3914         3288         2848
# unique           NaN          235          234          225          216
# top              NaN  Coffee Shop  Coffee Shop  Coffee Shop  Coffee Shop
# freq             NaN          375          238          214          167
# mean        1.756500          NaN          NaN          NaN          NaN
# std         2.127548          NaN          NaN          NaN          NaN
# min         0.000000          NaN          NaN          NaN          NaN
# 25%         0.000000          NaN          NaN          NaN          NaN
# 50%         0.000000          NaN          NaN          NaN          NaN
# 75%         5.000000          NaN          NaN          NaN          NaN
# max         5.000000          NaN          NaN          NaN          NaN
#
#               next5
# count          2560
# unique          219
# top     Coffee Shop
# freq            166
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
venues['num next'].value_counts().sort_index()
# Out:
# 0.0    5045
# 1.0    1041
# 2.0     626
# 3.0     440
# 4.0     288
# 5.0    2560
# Name: num next, dtype: int64

# %% [markdown]
# Let's look at venues in the Sports Bar category.

# %%
category = 'Sports Bar'
group = venues[venues['category'] == category]
group
# Out:
#       index                        id    category  num next  \
# 333     333  5a29fc9f9d6a191b4ec7caf4  Sports Bar       2.0
# 370     370  4f31d5efe4b057434ce9c989  Sports Bar       1.0
# 377     377  52f7dd7111d22027eea4c47f  Sports Bar       5.0
# 890     890  5875af81d4ab736b8e785bac  Sports Bar       2.0
# 1983   1983  54642cba498e50ec78b74e43  Sports Bar       4.0
# 2034   2034  4ac5aa87f964a52064b220e3  Sports Bar       5.0
# 2584   2584  561db7a3498e594adb2fa222  Sports Bar       1.0
# 3188   3188  4c2035fdb306c928eaac69b7  Sports Bar       2.0
# 4147   4147  4c33afec452620a10d02240f  Sports Bar       4.0
# 4153   4153  535c92de498eacad03e66b58  Sports Bar       1.0
# 5011   5011  4c6c84fc99b9236aecf4e2c9  Sports Bar       5.0
# 5397   5397  53f6bcec498eb0ce54b540ef  Sports Bar       5.0
# 7269   7269  4aff7f64f964a520193922e3  Sports Bar       5.0
# 8026   8026  5be86c4df05ca8002d83f2a0  Sports Bar       0.0
# 9856   9856  4aabedbcf964a520005b20e3  Sports Bar       5.0
#
#                        next1                  next2                   next3  \
# 333       Basketball Stadium       Basketball Court                     NaN
# 370       Basketball Stadium                    NaN                     NaN
# 377       Basketball Stadium  General Entertainment           Movie Theater
# 890   College Football Field         Soccer Stadium                     NaN
# 1983            Cocktail Bar         Shopping Plaza            Burger Joint
# 2034   Performing Arts Venue           Cocktail Bar          Shopping Plaza
# 2584      Basketball Stadium                    NaN                     NaN
# 3188                  Casino            Outlet Mall                     NaN
# 4147        Baseball Stadium         Baseball Field          Clothing Store
# 4153        Baseball Stadium                    NaN                     NaN
# 5011  College Football Field             Sports Bar               Rock Club
# 5397           Shopping Mall          Movie Theater          Chocolate Shop
# 7269       Korean Restaurant       Asian Restaurant       Korean Restaurant
# 8026                     NaN                    NaN                     NaN
# 9856            Concert Hall     Chinese Restaurant  College Football Field
#
#                      next4                 next5
# 333                    NaN                   NaN
# 370                    NaN                   NaN
# 377              Rock Club                   Bar
# 890                    NaN                   NaN
# 1983   Dumpling Restaurant                   NaN
# 2034                Bakery  Gym / Fitness Center
# 2584                   NaN                   NaN
# 3188                   NaN                   NaN
# 4147                Lounge                   NaN
# 4153                   NaN                   NaN
# 5011             Gastropub   American Restaurant
# 5397         Movie Theater           Music Venue
# 7269           Karaoke Bar    Seafood Restaurant
# 8026                   NaN                   NaN
# 9856  Fast Food Restaurant             Gastropub

# %% [markdown]
# Each row is a venue. Where do people go after visiting this venue? For each venue, Foursquare has given us up to five likely answers. We don't care about the identities of these venues, so we have saved their categories only. These categories are in columns next1 through next5.
#
# We start by counting occurrences of categories in the column next1:

# %%
group['next1'].value_counts()
# Out:
# Basketball Stadium        4
# College Football Field    2
# Baseball Stadium          2
# Casino                    1
# Cocktail Bar              1
# Korean Restaurant         1
# Shopping Mall             1
# Concert Hall              1
# Performing Arts Venue     1
# Name: next1, dtype: int64

# %% [markdown]
# We repeat this for columns next2 through next5, and combine the results:

# %%
MNPV = 5 #Maximum number of results from a nextvenues query (determined by Foursquare)
group_scores = pd.concat(
    [group['next' + str(i + 1)].value_counts()
     for i in range(MNPV)],
    axis=1, sort=False)
group_scores
# Out:
#                         next1  next2  next3  next4  next5
# Basketball Stadium        4.0    NaN    NaN    NaN    NaN
# College Football Field    2.0    NaN    1.0    NaN    NaN
# Baseball Stadium          2.0    NaN    NaN    NaN    NaN
# Casino                    1.0    NaN    NaN    NaN    NaN
# Cocktail Bar              1.0    1.0    NaN    NaN    NaN
# Korean Restaurant         1.0    NaN    1.0    NaN    NaN
# Shopping Mall             1.0    NaN    NaN    NaN    NaN
# Concert Hall              1.0    NaN    NaN    NaN    NaN
# Performing Arts Venue     1.0    NaN    NaN    NaN    NaN
# Asian Restaurant          NaN    1.0    NaN    NaN    NaN
# Baseball Field            NaN    1.0    NaN    NaN    NaN
# Shopping Plaza            NaN    1.0    1.0    NaN    NaN
# Outlet Mall               NaN    1.0    NaN    NaN    NaN
# Soccer Stadium            NaN    1.0    NaN    NaN    NaN
# Sports Bar                NaN    1.0    NaN    NaN    NaN
# General Entertainment     NaN    1.0    NaN    NaN    NaN
# Basketball Court          NaN    1.0    NaN    NaN    NaN
# Chinese Restaurant        NaN    1.0    NaN    NaN    NaN
# Movie Theater             NaN    1.0    1.0    1.0    NaN
# Rock Club                 NaN    NaN    1.0    1.0    NaN
# Chocolate Shop            NaN    NaN    1.0    NaN    NaN
# Clothing Store            NaN    NaN    1.0    NaN    NaN
# Burger Joint              NaN    NaN    1.0    NaN    NaN
# Lounge                    NaN    NaN    NaN    1.0    NaN
# Dumpling Restaurant       NaN    NaN    NaN    1.0    NaN
# Gastropub                 NaN    NaN    NaN    1.0    1.0
# Karaoke Bar               NaN    NaN    NaN    1.0    NaN
# Fast Food Restaurant      NaN    NaN    NaN    1.0    NaN
# Bakery                    NaN    NaN    NaN    1.0    NaN
# Music Venue               NaN    NaN    NaN    NaN    1.0
# American Restaurant       NaN    NaN    NaN    NaN    1.0
# Bar                       NaN    NaN    NaN    NaN    1.0
# Gym / Fitness Center      NaN    NaN    NaN    NaN    1.0
# Seafood Restaurant        NaN    NaN    NaN    NaN    1.0

# %% [markdown]
# We'd like to add up the total number of times people went to these other venues after a sports bar. Foursquare doesn't give us these numbers, but it does order the next venues using these numbers in descending order. Therefore we give higher weight to those earlier in the list. We make a wild guess that the best weights for columns next1 through next5 are 10, 9, 8, 7, and 6 respectively. Here are the weighted scores:

# %%
WFFR = 10 #Weight given to the first result of a nextvenues query (my choice)
group_scores = pd.concat(
    [group['next' + str(i + 1)].value_counts()*(WFFR - i)
     for i in range(MNPV)],
    axis=1, sort=False)
group_scores
# Out:
#                         next1  next2  next3  next4  next5
# Basketball Stadium       40.0    NaN    NaN    NaN    NaN
# College Football Field   20.0    NaN    8.0    NaN    NaN
# Baseball Stadium         20.0    NaN    NaN    NaN    NaN
# Casino                   10.0    NaN    NaN    NaN    NaN
# Cocktail Bar             10.0    9.0    NaN    NaN    NaN
# Korean Restaurant        10.0    NaN    8.0    NaN    NaN
# Shopping Mall            10.0    NaN    NaN    NaN    NaN
# Concert Hall             10.0    NaN    NaN    NaN    NaN
# Performing Arts Venue    10.0    NaN    NaN    NaN    NaN
# Asian Restaurant          NaN    9.0    NaN    NaN    NaN
# Baseball Field            NaN    9.0    NaN    NaN    NaN
# Shopping Plaza            NaN    9.0    8.0    NaN    NaN
# Outlet Mall               NaN    9.0    NaN    NaN    NaN
# Soccer Stadium            NaN    9.0    NaN    NaN    NaN
# Sports Bar                NaN    9.0    NaN    NaN    NaN
# General Entertainment     NaN    9.0    NaN    NaN    NaN
# Basketball Court          NaN    9.0    NaN    NaN    NaN
# Chinese Restaurant        NaN    9.0    NaN    NaN    NaN
# Movie Theater             NaN    9.0    8.0    7.0    NaN
# Rock Club                 NaN    NaN    8.0    7.0    NaN
# Chocolate Shop            NaN    NaN    8.0    NaN    NaN
# Clothing Store            NaN    NaN    8.0    NaN    NaN
# Burger Joint              NaN    NaN    8.0    NaN    NaN
# Lounge                    NaN    NaN    NaN    7.0    NaN
# Dumpling Restaurant       NaN    NaN    NaN    7.0    NaN
# Gastropub                 NaN    NaN    NaN    7.0    6.0
# Karaoke Bar               NaN    NaN    NaN    7.0    NaN
# Fast Food Restaurant      NaN    NaN    NaN    7.0    NaN
# Bakery                    NaN    NaN    NaN    7.0    NaN
# Music Venue               NaN    NaN    NaN    NaN    6.0
# American Restaurant       NaN    NaN    NaN    NaN    6.0
# Bar                       NaN    NaN    NaN    NaN    6.0
# Gym / Fitness Center      NaN    NaN    NaN    NaN    6.0
# Seafood Restaurant        NaN    NaN    NaN    NaN    6.0

# %% [markdown]
# We get the total score for each category by adding across the rows:

# %%
group_scores = group_scores.sum(axis=1)
group_scores
# Out:
# Basketball Stadium        40.0
# College Football Field    28.0
# Baseball Stadium          20.0
# Casino                    10.0
# Cocktail Bar              19.0
# Korean Restaurant         18.0
# Shopping Mall             10.0
# Concert Hall              10.0
# Performing Arts Venue     10.0
# Asian Restaurant           9.0
# Baseball Field             9.0
# Shopping Plaza            17.0
# Outlet Mall                9.0
# Soccer Stadium             9.0
# Sports Bar                 9.0
# General Entertainment      9.0
# Basketball Court           9.0
# Chinese Restaurant         9.0
# Movie Theater             24.0
# Rock Club                 15.0
# Chocolate Shop             8.0
# Clothing Store             8.0
# Burger Joint               8.0
# Lounge                     7.0
# Dumpling Restaurant        7.0
# Gastropub                 13.0
# Karaoke Bar                7.0
# Fast Food Restaurant       7.0
# Bakery                     7.0
# Music Venue                6.0
# American Restaurant        6.0
# Bar                        6.0
# Gym / Fitness Center       6.0
# Seafood Restaurant         6.0
# dtype: float64

# %% [markdown]
# Finally, we convert these scores to percentages by dividing by the total, and list the top five in descending order:

# %%
NRPC = 5 #Number of results to output per category (my choice)
group_percent = group_scores*100/group_scores.sum()
group_percent.sort_values(ascending=False, inplace=True)
leaders = group_percent.head(NRPC)
leaders
# Out:
# Basketball Stadium        10.126582
# College Football Field     7.088608
# Movie Theater              6.075949
# Baseball Stadium           5.063291
# Cocktail Bar               4.810127
# dtype: float64

# %% [markdown]
# Thus, we estimate that someone at a sports bar has a 10.1 percent chance of next visiting a basketball stadium, and that the next four most likely categories are college football field, movie theater, baseball stadium, and cocktail bar.
#
# Now we repeat this computation for all categories. We will only include categories where we have at least 10 venues with next venues, with a total of at least 20 next venues.

# %%
results_columns = ['# of Venues', '# of Venues With Next',
                   'Total # of Next Venues']
for i in range(1, NRPC + 1):
    results_columns += ['Next Category #' + str(i), 'Pct. #' + str(i)]
results_df = pd.DataFrame(columns=results_columns)

for category, group in venues.groupby('category'):
    num_venues = len(group)
    num_with_next = len(group[group['num next'] > 0])
    if num_with_next < 10:
        continue
    total_next = group['num next'].sum()
    if total_next < 20:
        continue
    results_df.loc[category, '# of Venues'] = num_venues
    results_df.loc[category, '# of Venues With Next'] = num_with_next
    results_df.loc[category, 'Total # of Next Venues'] = total_next
    group_scores = pd.concat(
        [group['next' + str(i + 1)].value_counts()*(WFFR - i)
         for i in range(MNPV)],
        axis=1, sort=False).sum(axis=1)
    group_percent = group_scores*100/group_scores.sum()
    group_percent.sort_values(ascending=False, inplace=True)
    leaders = group_percent.head(NRPC).reset_index()  
    for j in leaders.index:
        results_df.loc[category,
                       'Next Category #' + str(j + 1)
                      ] = leaders.loc[j, 'index']
        results_df.loc[category,
                       'Pct. #' + str(j + 1)
                      ] = leaders.loc[j, 0]        
    
print(results_df.shape)
results_df
# Out:
# (122, 13)
#                                 # of Venues # of Venues With Next  \
# American Restaurant                     154                   102
# Art Gallery                              87                    46
# Art Museum                               20                    14
# Arts & Crafts Store                      32                    18
# Asian Restaurant                         90                    36
# BBQ Joint                                36                    20
# Bakery                                  149                    73
# Bank                                     69                    47
# Bar                                     116                    97
# Big Box Store                            15                    15
# Bookstore                                32                    22
# Boutique                                 48                    28
# Breakfast Spot                           57                    42
# Brewery                                  17                    17
# Bubble Tea Shop                          28                    18
# Burger Joint                            183                    82
# Café                                    195                    98
# Candy Store                              17                    11
# Chinese Restaurant                      166                    95
# Clothing Store                          124                    76
# Cocktail Bar                             51                    44
# Coffee Shop                             375                   243
# Comedy Club                              16                    14
# Concert Hall                             15                    11
# Convenience Store                       190                    67
# Cosmetics Shop                           80                    37
# Deli / Bodega                            42                    14
# Department Store                         42                    26
# Dessert Shop                             52                    34
# Dim Sum Restaurant                       11                    10
# Diner                                    46                    34
# Discount Store                           49                    27
# Dive Bar                                 19                    14
# Donut Shop                               97                    25
# Farmers Market                           22                    14
# Fast Food Restaurant                    257                   125
# Flea Market                              17                    10
# Food Court                               25                    21
# Food Truck                              133                    22
# French Restaurant                        32                    25
# Fried Chicken Joint                      73                    21
# Frozen Yogurt Shop                       23                    12
# Furniture / Home Store                   64                    25
# Garden                                   26                    21
# Gas Station                              42                    20
# Gastropub                                23                    19
# General Entertainment                    17                    16
# Gift Shop                                45                    33
# Golf Course                              14                    10
# Grocery Store                           165                   104
# Gym                                      75                    33
# Gym / Fitness Center                     96                    35
# Hardware Store                           18                    11
# Historic Site                            24                    14
# History Museum                           19                    15
# Hot Dog Joint                            21                    13
# Hotel                                   114                    76
# Hotel Bar                                18                    17
# Ice Cream Shop                          101                    46
# Indian Restaurant                        32                    21
# Italian Restaurant                      109                    77
# Japanese Restaurant                      89                    52
# Juice Bar                                70                    39
# Korean Restaurant                       143                    82
# Latin American Restaurant                49                    14
# Lounge                                   42                    31
# Mediterranean Restaurant                 67                    40
# Men's Store                              24                    14
# Mexican Restaurant                      455                   169
# Middle Eastern Restaurant                27                    15
# Mobile Phone Shop                        67                    12
# Movie Theater                            41                    26
# Museum                                   39                    31
# Music Venue                              54                    29
# New American Restaurant                  42                    31
# Nightclub                                28                    15
# Noodle House                             24                    18
# Park                                    184                    74
# Performing Arts Venue                    23                    13
# Pet Store                                55                    27
# Pharmacy                                136                    80
# Pizza Place                             262                    75
# Playground                               26                    10
# Plaza                                    20                    15
# Poke Place                               19                    10
# Pub                                      14                    13
# Ramen Restaurant                         21                    19
# Record Shop                              17                    11
# Restaurant                              113                    40
# Salad Place                              20                    14
# Salon / Barbershop                       30                    14
# Sandwich Place                          203                    98
# Scenic Lookout                           27                    17
# Sculpture Garden                         10                    10
# Seafood Restaurant                      100                    39
# Shipping Store                           39                    20
# Shoe Store                               44                    22
# Shopping Mall                            37                    25
# Southern / Soul Food Restaurant          25                    12
# Spa                                      66                    18
# Sporting Goods Shop                      26                    17
# Sports Bar                               15                    14
# Steakhouse                               24                    22
# Supermarket                              37                    34
# Sushi Restaurant                         94                    68
# Taco Place                               89                    36
# Tea Room                                 26                    20
# Thai Restaurant                         107                    61
# Theater                                  63                    29
# Theme Park                               28                    25
# Theme Park Ride / Attraction             33                    26
# Thrift / Vintage Store                   42                    19
# Toy / Game Store                         13                    11
# Trail                                   147                    35
# Vegetarian / Vegan Restaurant            48                    31
# Vietnamese Restaurant                    34                    21
# Wine Bar                                 27                    16
# Wine Shop                                15                    13
# Wings Joint                              21                    11
# Women's Store                            21                    12
# Yoga Studio                              41                    27
# Zoo Exhibit                              28                    22
#
#                                 Total # of Next Venues  \
# American Restaurant                                399
# Art Gallery                                        156
# Art Museum                                          59
# Arts & Crafts Store                                 72
# Asian Restaurant                                   114
# BBQ Joint                                           73
# Bakery                                             242
# Bank                                               159
# Bar                                                413
# Big Box Store                                       66
# Bookstore                                           88
# Boutique                                            99
# Breakfast Spot                                     172
# Brewery                                             80
# Bubble Tea Shop                                     58
# Burger Joint                                       296
# Café                                               364
# Candy Store                                         45
# Chinese Restaurant                                 297
# Clothing Store                                     317
# Cocktail Bar                                       184
# Coffee Shop                                        923
# Comedy Club                                         59
# Concert Hall                                        45
# Convenience Store                                  193
# Cosmetics Shop                                     121
# Deli / Bodega                                       42
# Department Store                                   106
# Dessert Shop                                       116
# Dim Sum Restaurant                                  39
# Diner                                              132
# Discount Store                                      85
# Dive Bar                                            57
# Donut Shop                                          83
# Farmers Market                                      61
# Fast Food Restaurant                               350
# Flea Market                                         35
# Food Court                                          86
# Food Truck                                          51
# French Restaurant                                  113
# Fried Chicken Joint                                 59
# Frozen Yogurt Shop                                  49
# Furniture / Home Store                              92
# Garden                                              64
# Gas Station                                         46
# Gastropub                                           88
# General Entertainment                               58
# Gift Shop                                          121
# Golf Course                                         27
# Grocery Store                                      410
# Gym                                                109
# Gym / Fitness Center                               125
# Hardware Store                                      47
# Ramen Restaurant                                    Bar  8.59649
# Record Shop                                   Bookstore  5.28053
# Restaurant                                Shopping Mall  3.42651
# Salad Place                               Big Box Store  5.30452
# Salon / Barbershop                 Fast Food Restaurant   8.4507
# Sandwich Place                        Convenience Store  4.34004
# Scenic Lookout                            Shopping Mall  5.71429
# Sculpture Garden                          Historic Site  6.06061
# Seafood Restaurant                         Dessert Shop  3.68151
# Shipping Store                            Shopping Mall  5.31915
# Shoe Store                                Shopping Mall   5.8156
# Shopping Mall                             Shopping Mall  4.70085
# Southern / Soul Food Restaurant               Multiplex  4.70914
# Spa                                                 Spa  5.52147
# Sporting Goods Shop                         Outlet Mall  5.28302
# Sports Bar                                 Cocktail Bar  4.81013
# Steakhouse                                 Concert Hall  4.29752
# Supermarket                                 Coffee Shop  6.94554
# Sushi Restaurant                          Grocery Store  5.01792
# Taco Place                               Ice Cream Shop  4.14013
# Tea Room                                  Movie Theater  5.14019
# Thai Restaurant                          Ice Cream Shop  6.00364
# Theater                                            Park  4.88432
# Theme Park                                Historic Site  1.10254
# Theme Park Ride / Attraction                        Zoo  2.16216
# Thrift / Vintage Store                   Clothing Store  6.39033
# Toy / Game Store                    Sporting Goods Shop  5.94059
# Trail                                          Mountain  4.08805
# Vegetarian / Vegan Restaurant               Supermarket  4.41883
# Vietnamese Restaurant                     Big Box Store   6.6561
# Wine Bar                                   Cocktail Bar  4.60405
# Wine Shop                                 Shopping Mall  4.37956
# Wings Joint                              Ice Cream Shop  6.41509
# Women's Store                                 Juice Bar  4.88506
# Yoga Studio                                 Supermarket  6.09756
# Zoo Exhibit                        Fast Food Restaurant  1.90476

# %% [markdown]
# Thus, for 122 venue categories, we have recommendations for targeting advertising to people at those venues.

# %%
#Save results as a Markdown table
f = open("results.md", "w+")
f.write("| | # of Venues | # of Venues With Next | Total # of Next Venues | Next Category #1 | Pct. #1 | Next Category #2 | Pct. #2 | Next Category #3 | Pct. #3 | Next Category #4 | Pct. #4 | Next Category #5 | Pct. #5 |\n")
f.write("| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:| ---:|\n")
for category in results_df.index:
    f.write("| {0} | {1:.0f} | {2:.0f} | {3:.0f} | {4} | {5:.1f} | {6} | {7:.1f} | {8} | {9:.1f} | {10} | {11:.1f} | {12} | {13:.1f} |\n".format(
         category,
         results_df.loc[category, '# of Venues'],
         results_df.loc[category, '# of Venues With Next'],
         results_df.loc[category, 'Total # of Next Venues'],
         results_df.loc[category, 'Next Category #1'],
         results_df.loc[category, 'Pct. #1'],
         results_df.loc[category, 'Next Category #2'],
         results_df.loc[category, 'Pct. #2'],
         results_df.loc[category, 'Next Category #3'],
         results_df.loc[category, 'Pct. #3'],
         results_df.loc[category, 'Next Category #4'],
         results_df.loc[category, 'Pct. #4'],
         results_df.loc[category, 'Next Category #5'],
         results_df.loc[category, 'Pct. #5'])
           )

# %%
f.close()

# %%
results_df.sort_values(by="Pct. #1", ascending=False).head(10)
# Out:
#                              # of Venues # of Venues With Next  \
# Zoo Exhibit                           28                    22
# Theme Park                            28                    25
# Garden                                26                    21
# Theme Park Ride / Attraction          33                    26
# Golf Course                           14                    10
# Yoga Studio                           41                    27
# Thrift / Vintage Store                42                    19
# Trail                                147                    35
# Art Museum                            20                    14
# Wine Shop                             15                    13
#
#                              Total # of Next Venues  \
# Zoo Exhibit                                      89
# Theme Park                                      112
# Garden                                           64
# Theme Park Ride / Attraction                    113
# Golf Course                                      27
# Yoga Studio                                      65
# Thrift / Vintage Store                           70
# Trail                                           113
# Art Museum                                       59
# Wine Shop                                        50
#
#                                           Next Category #1  Pct. #1  \
# Zoo Exhibit                                    Zoo Exhibit  74.4218
# Theme Park                    Theme Park Ride / Attraction   45.645
# Garden                                              Garden  45.3704
# Theme Park Ride / Attraction                    Theme Park  41.5135
# Golf Course                                    Golf Course  33.4764
# Yoga Studio                                  Grocery Store  32.0557
# Thrift / Vintage Store              Thrift / Vintage Store  31.0881
# Trail                                                Trail   29.979
# Art Museum                                      Art Museum  28.3925
# Wine Shop                                    Grocery Store  27.9805
#
#                                           Next Category #2  Pct. #2  \
# Zoo Exhibit                                            Zoo  13.8776
# Theme Park                                      Theme Park   45.204
# Garden                                            Tea Room  16.1111
# Theme Park Ride / Attraction  Theme Park Ride / Attraction  39.4595
# Golf Course                                          Diner  8.58369
# Yoga Studio                                    Coffee Shop  17.9443
# Thrift / Vintage Store                       Big Box Store  7.59931
# Trail                                                 Park   16.457
# Art Museum                                     Coffee Shop  11.4823
# Wine Shop                              American Restaurant  7.05596
#
#                                           Next Category #3  Pct. #3  \
# Zoo Exhibit                   Theme Park Ride / Attraction  4.08163
# Theme Park                             American Restaurant  2.09482
# Garden                                              Museum  11.8519
# Theme Park Ride / Attraction                        Museum  2.81081
# Golf Course                                           Park  8.15451
# Yoga Studio                                      Juice Bar  8.01394
# Thrift / Vintage Store                       Shopping Mall  7.25389
# Trail                                          Observatory   10.587
# Art Museum                                Sculpture Garden  7.30689
# Wine Shop                                    Big Box Store  6.56934
#
#                                      Next Category #4  Pct. #4  \
# Zoo Exhibit                                 Gift Shop  1.90476
# Theme Park                                      Diner  1.54355
# Garden                                           Park  7.77778
# Theme Park Ride / Attraction    General Entertainment  2.27027
# Golf Course                       American Restaurant  6.43777
# Yoga Studio                                      Café  6.27178
# Thrift / Vintage Store                  Grocery Store  6.90846
# Trail                                  Scenic Lookout  9.85325
# Art Museum                    New American Restaurant  6.88935
# Wine Shop                                Cocktail Bar  4.86618
#
#                                   Next Category #5  Pct. #5
# Zoo Exhibit                   Fast Food Restaurant  1.90476
# Theme Park                           Historic Site  1.10254
# Garden                               Grocery Store  3.51852
# Theme Park Ride / Attraction                   Zoo  2.16216
# Golf Course                          Grocery Store  6.43777
# Yoga Studio                            Supermarket  6.09756
# Thrift / Vintage Store              Clothing Store  6.39033
# Trail                                     Mountain  4.08805
# Art Museum                           Historic Site  6.88935
# Wine Shop                            Shopping Mall  4.37956

# %%
#Save results to a file
results_df.to_csv('results.csv')
