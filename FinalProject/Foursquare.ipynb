# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files


import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import math
import random

# %%
CLIENT_ID = 'YLFUKJAOWG0KL1WHTO2HD105URFFUDZ1YTCA0NHWVBWBW3FI' # your Foursquare ID
CLIENT_SECRET = 'L1QRNAP5NRYRERCQBW40PBXTNNNBGWK4CGNYRIIOKRPT5KZ1' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# Our region of study will be a square, 25 kilometers by 25 kilometers, centered at 34.052200° N, 118.243700° W. These coordinates were obtained by searching Google for "los angeles lat/lon".
#
# We will use a spherical earth approximation to compute the latitudes and longitudes of the boundaries of this square, and the latitudes and longitudes of the boundaries of random points within this square. According to this approximation, one degree of latitude is 10<sup>7</sup>/90 meters, and one degree of longitude is cos(latitude)\*10<sup>7</sup>/90 meters.

# %%
la_lat, la_lon = (34.052200, -118.243700)
square_half_side = 12500 #meters

# %%
def north_east_of_la(north, east):
    '''Compute the latitude and longitude of a point in our
    study area, given its distance north/south and east/west
    of the center point
    
    Inputs:
        north: float; distance north of center point, in meters. 
            Use negative for points south of the center.
        east: float; distance east of center point, in meters. 
            Use negative for points west of the center.
            
    Returns: tuple (latitude, longitude), in degrees
    '''
    lat = la_lat + north*90/10**7
    lon = la_lon + east*90/(10**7*math.cos(lat*3.14159265359/180))
    return (lat, lon)

# %%
nw_corner = north_east_of_la(square_half_side, -square_half_side)
ne_corner = north_east_of_la(square_half_side, square_half_side)
sw_corner = north_east_of_la(-square_half_side, -square_half_side)
se_corner = north_east_of_la(-square_half_side, square_half_side)

# %%
map_of_study = folium.Map(location=[la_lat, la_lon], zoom_start=11)
folium.PolyLine(
    [nw_corner, ne_corner, se_corner, sw_corner, nw_corner]
    ).add_to(map_of_study)
map_of_study
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Let's create a function to query Foursquare for venues

# %%
def get_nearby_venues(x, y, radius=500, limit=100):
    '''
    Query Foursquare for venues near a particular point within the 
    study area, and return the IDs and categories of the venues. 
    Note that if limit > 100, Foursquare will return at most 100 venues.
    
    Inputs: 
        x: (float) x coordinate of the query point, in meters east 
            of the study center point
        y: (float) y coordinate of the query point, in meters north 
            of the study center point
        radius: (float) query radius, in meters
        limit: (int) maximum number of results to return
        
    Returns: a Series with venue IDs as the index and venue
        categories as the values
    '''
        
    (lat, lon) = north_east_of_la(y, x)
    venues_list=[]
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat,
            lon,
            radius, 
            limit)
    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    nearby_venues = pd.Series()
        
    # include only relevant information for each nearby venue
    for v in results:
        nearby_venues.loc[v['venue']['id']] = v['venue']['categories'][0]['name']
        
    return(nearby_venues)

# %% [markdown]
# We test `get_nearby_venues` at 50 random points within the study area:

# %%
for i in range(50):
    nv = get_nearby_venues(random.uniform(-square_half_side, square_half_side), 
                           random.uniform(-square_half_side, square_half_side), 
                           radius=1000, limit=150)
    print(len(nv))
# Out:
# 90
# 22
# 63
# 100
# 81
# 46
# 29
# 86
# 12
# 27
# 18
# 17
# 14
# 64
# 10
# 100
# 100
# 100
# 76
# 6
# 24
# 6
# 53
# 39
# 14
# 61
# 23
# 16
# 25
# 18
# 14
# 100
# 24
# 92
# 39
# 56
# 20
# 100
# 100
# 78
# 9
# 26
# 21
# 65
# 6
# 4
# 6
# 13
# 4
# 9

# %% [markdown]
# We see that several times, Foursquare returned 100 venues. Most likely, this means there were *n* > 100 venues within the query radius. We know that Foursquare is limited to returning 100 venues, but we don't know how Foursquare chooses 100 out of the _n_ venues. Its selection rule may cause an unknown bias. Therefore, when a query returns 100 venues, we do not use these results. However, if we  simply ignore these results, we are undersampling areas with a high density of venues. To avoid this problem, whenever a query returns 100 venues, we replace it with four more queries with half the radius. These four queries cover the same total area as the original query.

# %%
def get_nearby_venues_unbiased(x, y, radius=1000):
    '''
    Query Foursquare for venues near a particular point within the 
    study area, and return the IDs and categories of the venues. 
    Note that Foursquare will return at most 100 venues. 
    
    To ensure that Foursquare does not bias the results with
    unknown selection rules, we ignore the results of queries
    that return 100 venues. Instead, we execute queries for 
    four nearby points, using a radius half as large.
    
    Inputs: 
        x: (float) x coordinate of the query point, in meters east 
            of the study center point
        y: (float) y coordinate of the query point, in meters north 
            of the study center point
        radius: (float) query radius, in meters
        
    Returns: a DataFrame with a row for each venue found, with
        columns 'id' and 'category'
    '''
        
    limit = 100
    (lat, lon) = north_east_of_la(y, x)
    venues_list=[]
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat,
            lon,
            radius, 
            limit)
    # make the GET request
    json_received = requests.get(url).json()
    try:
        results = json_received["response"]['groups'][0]['items']
    except JSONDecodeError:
        print(json_received)
        results = []
        
    if len(results) < limit:
        nearby_venues = pd.DataFrame(columns=['id', 'category'])
        
        # include only relevant information for each nearby venue
        for v in results:
            nearby_venues = nearby_venues.append(
                {'id': v['venue']['id'],
                 'category': v['venue']['categories'][0]['name']
                }, ignore_index=True)        
        print(len(nearby_venues))
    else:
        quadrants = [get_nearby_venues_unbiased(x + i*radius/2, y + j*radius/2, radius/2)
                     for i in [-1, 1] for j in [-1, 1]
                    ]
        nearby_venues = (pd.concat(quadrants, axis=0, ignore_index=True)
                         .drop_duplicates(subset=['id'], keep='first')
                        )
    
    return(nearby_venues)

# %% [markdown]
# We call `get_nearby_venues_unbiased` repeatedly at random locations until we have at least 10,000 distinct venues. We use `drop_duplicates` to ensure they are distinct.

# %%
#Collect required number of venues
venues_to_find = 10000
radius = 1000

#Query centers lie within a smaller square, so that the query
#circle stays within the study area
query_square_half_side = square_half_side - radius

venues = pd.DataFrame(columns=['id', 'category'])
centers_chosen = 0
while len(venues) < venues_to_find:
    random_x = random.uniform(-query_square_half_side,
                              query_square_half_side)
    random_y = random.uniform(-query_square_half_side,
                              query_square_half_side)
    centers_chosen += 1
    new_venues = get_nearby_venues_unbiased(random_x, random_y, radius)
    venues = (venues.append(new_venues, ignore_index=True, sort=False)
              .drop_duplicates(subset=['id'], keep='first')
             )
    print((centers_chosen, len(new_venues), len(venues)))
# Out:
# 39
# (1, 39, 39)
# 23
# 42
# 44
# 39
# (2, 148, 187)
# 29
# (3, 29, 216)
# 13
# (4, 13, 229)
# 17
# (5, 17, 246)
# 21
# (6, 21, 267)
# 24
# (7, 24, 291)
# 11
# (8, 11, 302)
# 79
# (9, 79, 381)
# 5
# (10, 5, 386)
# 27
# (11, 27, 413)
# 95
# 31
# 21
# 15
# (12, 162, 575)
# 70
# (13, 70, 645)
# 59
# (14, 59, 704)
# 27
# (15, 27, 731)
# 90
# (16, 90, 821)
# 15
# (17, 15, 836)
# 34
# (18, 34, 869)
# 28
# (19, 28, 897)
# 30
# (20, 30, 927)
# 87
# (21, 87, 1014)
# 12
# (22, 12, 1026)
# 50
# 72
# 71
# 50
# (23, 243, 1169)
# 29
# (24, 29, 1198)
# 33
# (25, 33, 1231)
# 93
# 9
# 64
# 20
# (26, 186, 1411)
# 66
# (27, 66, 1477)
# 8
# (28, 8, 1485)
# 32
# (29, 32, 1493)
# 21
# (30, 21, 1513)
# 82
# (31, 82, 1581)
# 59
# (32, 59, 1629)
# 59
# (33, 59, 1685)
# 88
# (34, 88, 1773)
# 12
# (35, 12, 1783)
# 26
# (36, 26, 1805)
# 50
# (37, 50, 1855)
# 20
# (38, 20, 1875)
# 30
# (39, 30, 1889)
# 21
# (40, 21, 1900)
# 48
# (41, 48, 1928)
# 54
# (42, 54, 1982)
# 39
# (43, 39, 2021)
# 17
# (44, 17, 2027)
# 30
# (45, 30, 2039)
# 28
# (46, 28, 2067)
# 41
# (47, 41, 2079)
# 25
# (48, 25, 2093)
# 17
# (49, 17, 2104)
# 73
# (50, 73, 2177)
# 26
# (51, 26, 2203)
# 16
# (52, 16, 2212)
# 30
# (53, 30, 2240)
# 37
# (54, 37, 2250)
# 42
# 61
# 24
# 48
# 1
# 54
# 79
# (55, 309, 2559)
# 53
# (56, 53, 2612)
# 44
# (57, 44, 2638)
# 41
# (58, 41, 2679)
# 62
# (59, 62, 2734)
# 26
# (60, 26, 2760)
# 74
# (61, 74, 2834)
# 26
# (62, 26, 2859)
# 2
# 46
# 11
# 32
# (63, 91, 2922)
# 28
# (64, 28, 2950)
# 23
# (65, 23, 2967)
# 34
# 59
# 29
# 27
# (66, 149, 3116)
# 20
# (67, 20, 3133)
# 66
# (68, 66, 3155)
# 77
# (69, 77, 3230)
# 18
# (70, 18, 3248)
# 47
# (71, 47, 3291)
# 59
# (72, 59, 3293)
# 36
# (73, 36, 3329)
# 24
# (74, 24, 3350)
# 28
# (75, 28, 3378)
# 14
# (76, 14, 3392)
# 30
# (77, 30, 3406)
# 16
# (78, 16, 3422)
# 9
# (79, 9, 3425)
# 84
# (80, 84, 3509)
# 9
# (81, 9, 3514)
# 52
# (82, 52, 3518)
# 18
# (83, 18, 3533)
# 57
# (84, 57, 3562)
# 20
# (85, 20, 3578)
# 30
# (86, 30, 3586)
# 39
# (87, 39, 3619)
# 30
# (88, 30, 3649)
# 9
# (89, 9, 3649)
# 14
# (90, 14, 3663)
# 49
# (91, 49, 3712)
# 11
# (92, 11, 3720)
# 93
# (93, 93, 3807)
# 27
# (94, 27, 3821)
# 63
# (95, 63, 3864)
# 77
# 43
# 17
# 24
# (96, 161, 3980)
# 13
# (97, 13, 3980)
# 30
# (98, 30, 3986)
# 18
# (99, 18, 3995)
# 29
# 58
# 35
# 14
# (100, 136, 4027)
# 30
# (101, 30, 4050)
# 44
# 48
# 9
# 10
# (102, 111, 4115)
# 31
# (103, 31, 4142)
# 15
# (104, 15, 4157)
# 44
# (105, 44, 4201)
# 77
# (106, 77, 4245)
# 34
# (107, 34, 4274)
# 38
# (108, 38, 4293)
# 75
# (109, 75, 4342)
# 6
# (110, 6, 4347)
# 30
# (111, 30, 4348)
# 16
# (112, 16, 4356)
# 35
# (113, 35, 4377)
# 66
# (114, 66, 4383)
# 20
# (115, 20, 4403)
# 33
# (116, 33, 4433)
# 94
# (117, 94, 4504)
# 51
# (118, 51, 4550)
# 37
# (119, 37, 4552)
# 40
# (120, 40, 4588)
# 16
# (121, 16, 4591)
# 88
# (122, 88, 4679)
# 37
# (123, 37, 4716)
# 21
# (124, 21, 4724)
# 71
# (125, 71, 4729)
# 24
# (126, 24, 4734)
# 27
# (127, 27, 4753)
# 14
# (128, 14, 4762)
# 24
# (129, 24, 4772)
# 42
# (130, 42, 4794)
# 15
# (131, 15, 4806)
# 16
# (132, 16, 4815)
# 28
# 51
# 44
# 85
# (133, 208, 4864)
# 10
# (134, 10, 4873)
# 29
# (135, 29, 4879)
# 59
# (136, 59, 4938)
# 36
# 33
# 55
# 21
# (137, 145, 4999)
# 21
# (138, 21, 5017)
# 29
# (139, 29, 5039)
# 27
# (140, 27, 5053)
# 31
# (141, 31, 5068)
# 25
# (142, 25, 5076)
# 16
# (143, 16, 5078)
# 28
# (144, 28, 5103)
# 85
# (145, 85, 5147)
# 58
# 30
# 61
# 14
# (146, 163, 5190)
# 16
# (147, 16, 5190)
# 61
# (148, 61, 5225)
# 23
# (149, 23, 5226)
# 32
# (150, 32, 5246)
# 40
# 32
# 42
# 6
# (151, 120, 5331)
# 53
# (152, 53, 5338)
# 48
# (153, 48, 5364)
# 11
# 14
# 20
# 29
# 75
# 41
# 28
# (154, 218, 5508)
# 74
# (155, 74, 5539)
# 25
# (156, 25, 5543)
# 18
# (157, 18, 5553)
# 79
# (158, 79, 5607)
# 12
# (159, 12, 5613)
# 27
# 2
# 29
# 19
# 70
# 37
# 28
# (160, 212, 5646)
# 38
# (161, 38, 5684)
# 45
# (162, 45, 5710)
# 19
# (163, 19, 5729)
# 26
# (164, 26, 5753)
# 37
# (165, 37, 5775)
# 95
# (166, 95, 5817)
# 88
# (167, 88, 5842)
# 90
# (168, 90, 5900)
# 55
# (169, 55, 5940)
# 4
# (170, 4, 5942)
# 78
# (171, 78, 5955)
# 23
# (172, 23, 5973)
# 73
# (173, 73, 5976)
# 26
# (174, 26, 5987)
# 14
# (175, 14, 5995)
# 47
# (176, 47, 6029)
# 22
# (177, 22, 6030)
# 35
# (178, 35, 6039)
# 43
# (179, 43, 6077)
# 18
# (180, 18, 6094)
# 45
# (181, 45, 6100)
# 31
# (182, 31, 6109)
# 21
# (183, 21, 6116)
# 21
# (184, 21, 6117)
# 51
# 34
# 25
# 32
# (185, 142, 6118)
# 16
# (186, 16, 6120)
# 45
# (187, 45, 6135)
# 54
# (188, 54, 6148)
# 27
# (189, 27, 6153)
# 32
# (190, 32, 6153)
# 98
# (191, 98, 6237)
# 99
# (192, 99, 6276)
# 2
# (193, 2, 6278)
# 67
# (194, 67, 6317)
# 14
# (195, 14, 6319)
# 20
# 52
# 30
# 72
# (196, 174, 6453)
# 70
# (197, 70, 6521)
# 25
# (198, 25, 6521)
# 6
# (199, 6, 6522)
# 19
# (200, 19, 6526)
# 83
# (201, 83, 6528)
# 69
# (202, 69, 6544)
# 49
# (203, 49, 6567)
# 47
# 58
# 77
# 70
# (204, 252, 6679)
# 22
# (205, 22, 6687)
# 25
# (206, 25, 6698)
# 58
# (207, 58, 6698)
# 79
# (208, 79, 6734)
# 23
# (209, 23, 6740)
# 46
# 51
# 65
# 27
# (210, 189, 6839)
# 34
# (211, 34, 6847)
# 20
# 20
# 23
# 17
# (212, 80, 6873)
# 28
# (213, 28, 6876)
# 6
# (214, 6, 6880)
# 74
# (215, 74, 6939)
# 78
# (216, 78, 6960)
# 72
# 63
# 21
# 12
# (217, 168, 6982)
# 50
# (218, 50, 7008)
# 25
# (219, 25, 7020)
# 40
# (220, 40, 7020)
# 68
# (221, 68, 7078)
# 91
# (222, 91, 7079)
# 18
# (223, 18, 7085)
# 39
# (224, 39, 7113)
# 14
# (225, 14, 7120)
# 91
# (226, 91, 7131)
# 99
# (227, 99, 7168)
# 24
# 31
# 24
# 17
# 32
# 33
# 24
# (228, 185, 7348)
# 42
# (229, 42, 7380)
# 35
# (230, 35, 7386)
# 68
# (231, 68, 7390)
# 29
# 21
# 17
# 14
# (232, 81, 7469)
# 26
# (233, 26, 7471)
# 28
# (234, 28, 7499)
# 24
# (235, 24, 7507)
# 49
# (236, 49, 7547)
# 21
# (237, 21, 7552)
# 45
# (238, 45, 7579)
# 30
# (239, 30, 7599)
# 42
# (240, 42, 7602)
# 49
# (241, 49, 7629)
# 42
# 75
# 12
# 3
# (242, 132, 7638)
# 83
# 51
# 21
# 46
# (243, 201, 7837)
# 64
# 27
# 72
# 26
# (244, 189, 7921)
# 51
# (245, 51, 7933)
# 12
# (246, 12, 7935)
# 95
# (247, 95, 7957)
# 28
# (248, 28, 7967)
# 16
# (249, 16, 7971)
# 36
# (250, 36, 7971)
# 62
# (251, 62, 8005)
# 14
# (252, 14, 8009)
# 56
# (253, 56, 8053)
# 12
# (254, 12, 8061)
# 16
# (255, 16, 8067)
# 11
# (256, 11, 8068)
# 31
# (257, 31, 8075)
# 7
# (258, 7, 8077)
# 26
# (259, 26, 8082)
# 78
# (260, 78, 8102)
# 92
# (261, 92, 8133)
# 45
# (262, 45, 8163)
# 42
# 19
# 24
# 5
# (263, 90, 8186)
# 79
# (264, 79, 8186)
# 61
# (265, 61, 8237)
# 16
# (266, 16, 8244)
# 39
# (267, 39, 8247)
# 96
# (268, 96, 8321)
# 43
# (269, 43, 8329)
# 64
# (270, 64, 8329)
# 38
# (271, 38, 8340)
# 19
# (272, 19, 8349)
# 25
# (273, 25, 8364)
# 24
# (274, 24, 8364)
# 26
# (275, 26, 8369)
# 7
# (276, 7, 8371)
# 23
# (277, 23, 8375)
# 31
# (278, 31, 8380)
# 12
# (279, 12, 8380)
# 19
# (280, 19, 8386)
# 43
# (281, 43, 8396)
# 50
# (282, 50, 8412)
# 19
# (283, 19, 8412)
# 36
# (284, 36, 8440)
# 59
# (285, 59, 8443)
# 34
# (286, 34, 8446)
# 24
# (287, 24, 8447)
# 17
# (288, 17, 8448)
# 13
# (289, 13, 8460)
# 76
# (290, 76, 8470)
# 11
# (291, 11, 8475)
# 17
# (292, 17, 8478)
# 38
# (293, 38, 8480)
# 29
# (294, 29, 8493)
# 12
# (295, 12, 8493)
# 34
# (296, 34, 8496)
# 45
# 92
# 2
# 18
# (297, 157, 8603)
# 28
# (298, 28, 8610)
# 47
# (299, 47, 8622)
# 11
# (300, 11, 8628)
# 30
# (301, 30, 8629)
# 71
# (302, 71, 8672)
# 24
# (303, 24, 8680)
# 62
# (304, 62, 8694)
# 24
# (305, 24, 8702)
# 40
# (306, 40, 8712)
# 29
# (307, 29, 8713)
# 38
# (308, 38, 8713)
# 20
# (309, 20, 8730)
# 93
# 45
# 39
# 55
# (310, 232, 8730)
# 14
# (311, 14, 8732)
# 48
# (312, 48, 8742)
# 58
# (313, 58, 8761)
# 9
# (314, 9, 8768)
# 49
# (315, 49, 8768)
# 24
# (316, 24, 8768)
# 15
# (317, 15, 8776)
# 28
# 44
# 64
# 92
# (318, 228, 8871)
# 36
# (319, 36, 8900)
# 20
# (320, 20, 8901)
# 19
# (321, 19, 8903)
# 33
# (322, 33, 8913)
# 30
# (323, 30, 8914)
# 24
# 13
# 16
# 34
# (324, 87, 8933)
# 70
# (325, 70, 8933)
# 31
# 56
# 29
# 56
# (326, 172, 8951)
# 52
# (327, 52, 8973)
# 53
# (328, 53, 8977)
# 38
# (329, 38, 8992)
# 32
# (330, 32, 8993)
# 29
# (331, 29, 9022)
# 2
# 46
# 10
# 59
# (332, 117, 9063)
# 30
# (333, 30, 9063)
# 15
# (334, 15, 9063)
# 75
# (335, 75, 9064)
# 12
# (336, 12, 9070)
# 69
# (337, 69, 9077)
# 17
# (338, 17, 9077)
# 41
# (339, 41, 9077)
# 22
# (340, 22, 9085)
# 68
# (341, 68, 9085)
# 67
# (342, 67, 9104)
# 31
# (343, 31, 9113)
# 14
# (344, 14, 9113)
# 21
# (345, 21, 9118)
# 17
# (346, 17, 9124)
# 39
# (347, 39, 9133)
# 27
# (348, 27, 9136)
# 9
# (349, 9, 9138)
# 14
# (350, 14, 9139)
# 29
# (351, 29, 9146)
# 48
# (352, 48, 9166)
# 67
# 42
# 20
# 28
# 32
# 44
# 77
# (353, 310, 9331)
# 50
# (354, 50, 9339)
# 71
# (355, 71, 9349)
# 9
# (356, 9, 9351)
# 20
# (357, 20, 9351)
# 88
# (358, 88, 9354)
# 19
# 22
# 2
# 17
# 32
# 75
# 14
# (359, 181, 9376)
# 22
# (360, 22, 9378)
# 6
# 76
# 21
# 30
# (361, 133, 9398)
# 87
# (362, 87, 9413)
# 23
# 38
# 31
# 40
# (363, 132, 9425)
# 27
# (364, 27, 9432)
# 38
# 90
# 38
# 33
# (365, 199, 9479)
# 22
# (366, 22, 9488)
# 76
# (367, 76, 9499)
# 39
# (368, 39, 9500)
# 31
# (369, 31, 9501)
# 28
# (370, 28, 9501)
# 1
# (371, 1, 9502)
# 45
# (372, 45, 9528)
# 96
# (373, 96, 9529)
# 29
# (374, 29, 9529)
# 57
# (375, 57, 9530)
# 89
# (376, 89, 9541)
# 7
# (377, 7, 9544)
# 15
# (378, 15, 9545)
# 8
# (379, 8, 9551)
# 88
# (380, 88, 9565)
# 71
# (381, 71, 9567)
# 6
# (382, 6, 9568)
# 31
# (383, 31, 9599)
# 32
# (384, 32, 9604)
# 30
# (385, 30, 9605)
# 23
# (386, 23, 9608)
# 19
# (387, 19, 9610)
# 49
# (388, 49, 9610)
# 38
# (389, 38, 9613)
# 8
# (390, 8, 9614)
# 29
# (391, 29, 9620)
# 21
# (392, 21, 9622)
# 90
# (393, 90, 9647)
# 7
# (394, 7, 9648)
# 24
# (395, 24, 9650)
# 39
# (396, 39, 9670)
# 46
# (397, 46, 9682)
# 30
# (398, 30, 9683)
# 12
# (399, 12, 9683)
# 31
# (400, 31, 9686)
# 75
# (401, 75, 9693)
# 12
# (402, 12, 9700)
# 58
# (403, 58, 9729)
# 84
# (404, 84, 9729)
# 34
# 93
# 39
# 72
# (405, 238, 9755)
# 21
# (406, 21, 9763)
# 34
# (407, 34, 9768)
# 63
# (408, 63, 9770)
# 7
# (409, 7, 9770)
# 59
# (410, 59, 9772)
# 23
# (411, 23, 9773)
# 17
# (412, 17, 9775)
# 87
# (413, 87, 9814)
# 13
# (414, 13, 9814)
# 24
# (415, 24, 9816)
# 47
# (416, 47, 9816)
# 17
# 56
# 34
# 17
# (417, 124, 9816)
# 45
# (418, 45, 9852)
# 89
# (419, 89, 9868)
# 90
# (420, 90, 9869)
# 12
# (421, 12, 9876)
# 81
# (422, 81, 9878)
# 21
# (423, 21, 9879)
# 27
# (424, 27, 9884)
# 36
# 19
# 1
# 72
# 13
# 4
# 56
# (425, 201, 9887)
# 22
# (426, 22, 9889)
# 57
# (427, 57, 9897)
# 32
# (428, 32, 9909)
# 5
# (429, 5, 9909)
# 23
# (430, 23, 9916)
# 17
# (431, 17, 9919)
# 51
# (432, 51, 9921)
# 42
# (433, 42, 9921)
# 51
# (434, 51, 9924)
# 58
# 60
# 0
# 8
# (435, 126, 9937)
# 15
# 30
# 53
# 2
# 21
# 37
# 92
# (436, 250, 10016)

# %%
venues.to_csv('venues.csv')

# %%
venues.describe()
# Out:
#                               id            category
# count                      10016               10016
# unique                     10016                 451
# top     5ab455de8d0a531174f5a5f5  Mexican Restaurant
# freq                           1                 429

# %% [markdown]
# We have found a total of 10,016 venues. It will be useful to know how many are in each category:

# %%
categories = venues['category'].value_counts()
categories.to_csv('categories.csv')

# %%
venues = venues.reset_index()

# %% [markdown]
# In the cell below, for each of these 10,016 venues, we query Foursquare for its "next venues," which means the most common venues that a user checks in at after checking in at this venue. This takes about two hours.
#
# Occasionally, while the cell below is executing, Foursquare fails to return a valid result. In this case, the code below will print the JSON and continue. Allow the cell to execute until it finishes. Then replace `for i in venues.index:` with `for i in venues[pd.isna(venues['num next'])].index:` and re-execute the cell. This will repeat the queries that were not successful.

# %%
for i in venues.index:
    
#for i in venues[pd.isna(venues['num next'])].index:

    venue_id = venues.loc[i, 'id']
    url = 'https://api.foursquare.com/v2/venues/{}/nextvenues?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    json_received = requests.get(url).json()
    try:
        num_next_venues = json_received['response']['nextVenues']['count']
        next_venues = json_received['response']['nextVenues']['items']
        venues.loc[i, 'num next'] = num_next_venues
        for j in range(num_next_venues):
            venues.loc[i, 'next' + str(j + 1)] = next_venues[j]['categories'][0]['name']
    except KeyError:
        print(i)
        print(json_received)
        
    if i%100 == 0:
        print(i)
        venues.to_csv('venuesWithNext.csv')
# Out:
# 10000

# %%
venues.describe(include='all')
# Out:
#                index                        id            category  \
# count   10016.000000                     10016               10016
# unique           NaN                     10016                 451
# top              NaN  5ab455de8d0a531174f5a5f5  Mexican Restaurant
# freq             NaN                         1                 429
# mean     5007.591753                       NaN                 NaN
# std      2891.672768                       NaN                 NaN
# min         0.000000                       NaN                 NaN
# 25%      2503.750000                       NaN                 NaN
# 50%      5007.500000                       NaN                 NaN
# 75%      7511.250000                       NaN                 NaN
# max     10099.000000                       NaN                 NaN
#
#             num next        next1        next2        next3        next4  \
# count   10016.000000         4825         3788         3187         2768
# unique           NaN          229          227          220          219
# top              NaN  Coffee Shop  Coffee Shop  Coffee Shop  Coffee Shop
# freq             NaN          368          250          241          181
# mean        1.703474          NaN          NaN          NaN          NaN
# std         2.116934          NaN          NaN          NaN          NaN
# min         0.000000          NaN          NaN          NaN          NaN
# 25%         0.000000          NaN          NaN          NaN          NaN
# 50%         0.000000          NaN          NaN          NaN          NaN
# 75%         4.000000          NaN          NaN          NaN          NaN
# max         5.000000          NaN          NaN          NaN          NaN
#
#               next5
# count          2494
# unique          221
# top     Coffee Shop
# freq            156
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# Let's look at venues in the Sports Bar category.

# %%
category = 'Sports Bar'
group = venues[venues['category'] == category]
group
# Out:
#       index                        id    category  num next  \
# 436     436  54642cba498e50ec78b74e43  Sports Bar       4.0
# 2646   2646  4c33afec452620a10d02240f  Sports Bar       4.0
# 2650   2650  535c92de498eacad03e66b58  Sports Bar       1.0
# 3591   3591  4c2035fdb306c928eaac69b7  Sports Bar       2.0
# 6004   6004  5a29fc9f9d6a191b4ec7caf4  Sports Bar       2.0
# 6014   6014  4f31d5efe4b057434ce9c989  Sports Bar       1.0
# 7243   7243  561db7a3498e594adb2fa222  Sports Bar       1.0
# 8186   8186  5875af81d4ab736b8e785bac  Sports Bar       2.0
# 9182   9182  52f7dd7111d22027eea4c47f  Sports Bar       5.0
# 9451   9451  4aff7f64f964a520193922e3  Sports Bar       5.0
# 9789   9789  4c6c84fc99b9236aecf4e2c9  Sports Bar       5.0
#
#                        next1                  next2              next3  \
# 436             Cocktail Bar         Shopping Plaza       Burger Joint
# 2646        Baseball Stadium         Baseball Field     Clothing Store
# 2650        Baseball Stadium                    NaN                NaN
# 3591                  Casino            Outlet Mall                NaN
# 6004      Basketball Stadium       Basketball Court                NaN
# 6014      Basketball Stadium                    NaN                NaN
# 7243      Basketball Stadium                    NaN                NaN
# 8186  College Football Field         Soccer Stadium                NaN
# 9182      Basketball Stadium  General Entertainment      Movie Theater
# 9451       Korean Restaurant       Asian Restaurant  Korean Restaurant
# 9789  College Football Field             Sports Bar          Rock Club
#
#                     next4                next5
# 436   Dumpling Restaurant                  NaN
# 2646               Lounge                  NaN
# 2650                  NaN                  NaN
# 3591                  NaN                  NaN
# 6004                  NaN                  NaN
# 6014                  NaN                  NaN
# 7243                  NaN                  NaN
# 8186                  NaN                  NaN
# 9182            Rock Club                  Bar
# 9451          Karaoke Bar   Seafood Restaurant
# 9789            Gastropub  American Restaurant

# %% [markdown]
# Each row is a venue. Where do people go after visiting this venue? For each venue, Foursquare has given us up to five likely answers. We don't care about the identities of these venues, so we have saved their categories only. These categories are in columns next1 through next5.
#
# We start by counting occurrences of categories in the column next1:

# %%
group['next1'].value_counts()
# Out:
# Basketball Stadium        4
# Baseball Stadium          2
# College Football Field    2
# Casino                    1
# Korean Restaurant         1
# Cocktail Bar              1
# Name: next1, dtype: int64

# %% [markdown]
# We repeat this for columns next2 through next5, and combine the results:

# %%
MNPV = 5 #Maximum number of results from a nextvenues query (determined by Foursquare)
group_scores = pd.concat(
    [group['next' + str(i + 1)].value_counts()
     for i in range(MNPV)],
    axis=1, sort=False)
group_scores
# Out:
#                         next1  next2  next3  next4  next5
# Basketball Stadium        4.0    NaN    NaN    NaN    NaN
# Baseball Stadium          2.0    NaN    NaN    NaN    NaN
# College Football Field    2.0    NaN    NaN    NaN    NaN
# Casino                    1.0    NaN    NaN    NaN    NaN
# Korean Restaurant         1.0    NaN    1.0    NaN    NaN
# Cocktail Bar              1.0    NaN    NaN    NaN    NaN
# Asian Restaurant          NaN    1.0    NaN    NaN    NaN
# Basketball Court          NaN    1.0    NaN    NaN    NaN
# General Entertainment     NaN    1.0    NaN    NaN    NaN
# Baseball Field            NaN    1.0    NaN    NaN    NaN
# Shopping Plaza            NaN    1.0    NaN    NaN    NaN
# Outlet Mall               NaN    1.0    NaN    NaN    NaN
# Sports Bar                NaN    1.0    NaN    NaN    NaN
# Soccer Stadium            NaN    1.0    NaN    NaN    NaN
# Movie Theater             NaN    NaN    1.0    NaN    NaN
# Rock Club                 NaN    NaN    1.0    1.0    NaN
# Clothing Store            NaN    NaN    1.0    NaN    NaN
# Burger Joint              NaN    NaN    1.0    NaN    NaN
# Karaoke Bar               NaN    NaN    NaN    1.0    NaN
# Gastropub                 NaN    NaN    NaN    1.0    NaN
# Dumpling Restaurant       NaN    NaN    NaN    1.0    NaN
# Lounge                    NaN    NaN    NaN    1.0    NaN
# Bar                       NaN    NaN    NaN    NaN    1.0
# Seafood Restaurant        NaN    NaN    NaN    NaN    1.0
# American Restaurant       NaN    NaN    NaN    NaN    1.0

# %% [markdown]
# We'd like to add up the total number of times people went to these other venues after a sports bar. Foursquare doesn't give us these numbers, but it does order the next venues using these numbers in descending order. Therefore we give higher weight to those earlier in the list. We make a wild guess that the best weights for columns next1 through next5 are 10, 9, 8, 7, and 6 respectively. Here are the weighted scores:

# %%
WFFR = 10 #Weight given to the first result of a nextvenues query (my choice)
group_scores = pd.concat(
    [group['next' + str(i + 1)].value_counts()*(WFFR - i)
     for i in range(MNPV)],
    axis=1, sort=False)
group_scores
# Out:
#                         next1  next2  next3  next4  next5
# Basketball Stadium       40.0    NaN    NaN    NaN    NaN
# Baseball Stadium         20.0    NaN    NaN    NaN    NaN
# College Football Field   20.0    NaN    NaN    NaN    NaN
# Casino                   10.0    NaN    NaN    NaN    NaN
# Korean Restaurant        10.0    NaN    8.0    NaN    NaN
# Cocktail Bar             10.0    NaN    NaN    NaN    NaN
# Asian Restaurant          NaN    9.0    NaN    NaN    NaN
# Basketball Court          NaN    9.0    NaN    NaN    NaN
# General Entertainment     NaN    9.0    NaN    NaN    NaN
# Baseball Field            NaN    9.0    NaN    NaN    NaN
# Shopping Plaza            NaN    9.0    NaN    NaN    NaN
# Outlet Mall               NaN    9.0    NaN    NaN    NaN
# Sports Bar                NaN    9.0    NaN    NaN    NaN
# Soccer Stadium            NaN    9.0    NaN    NaN    NaN
# Movie Theater             NaN    NaN    8.0    NaN    NaN
# Rock Club                 NaN    NaN    8.0    7.0    NaN
# Clothing Store            NaN    NaN    8.0    NaN    NaN
# Burger Joint              NaN    NaN    8.0    NaN    NaN
# Karaoke Bar               NaN    NaN    NaN    7.0    NaN
# Gastropub                 NaN    NaN    NaN    7.0    NaN
# Dumpling Restaurant       NaN    NaN    NaN    7.0    NaN
# Lounge                    NaN    NaN    NaN    7.0    NaN
# Bar                       NaN    NaN    NaN    NaN    6.0
# Seafood Restaurant        NaN    NaN    NaN    NaN    6.0
# American Restaurant       NaN    NaN    NaN    NaN    6.0

# %% [markdown]
# We get the total score for each category by adding across the rows:

# %%
group_scores = group_scores.sum(axis=1)
group_scores
# Out:
# Basketball Stadium        40.0
# Baseball Stadium          20.0
# College Football Field    20.0
# Casino                    10.0
# Korean Restaurant         18.0
# Cocktail Bar              10.0
# Asian Restaurant           9.0
# Basketball Court           9.0
# General Entertainment      9.0
# Baseball Field             9.0
# Shopping Plaza             9.0
# Outlet Mall                9.0
# Sports Bar                 9.0
# Soccer Stadium             9.0
# Movie Theater              8.0
# Rock Club                 15.0
# Clothing Store             8.0
# Burger Joint               8.0
# Karaoke Bar                7.0
# Gastropub                  7.0
# Dumpling Restaurant        7.0
# Lounge                     7.0
# Bar                        6.0
# Seafood Restaurant         6.0
# American Restaurant        6.0
# dtype: float64

# %% [markdown]
# Finally, we convert these scores to percentages by dividing by the total, and list the top five in descending order:

# %%
NRPC = 5 #Number of results to output per category (my choice)
group_percent = group_scores*100/group_scores.sum()
group_percent.sort_values(ascending=False, inplace=True)
leaders = group_percent.head(NRPC)
leaders
# Out:
# Basketball Stadium        14.545455
# Baseball Stadium           7.272727
# College Football Field     7.272727
# Korean Restaurant          6.545455
# Rock Club                  5.454545
# dtype: float64

# %% [markdown]
# Thus, we estimate that someone at a sports bar has a 14.5 percent chance of next visiting a basketball stadium, and that the next four most likely categories are baseball stadium, college football field, Korean restaurant, and rock club.
#
# Now we repeat this computation for all categories. We will only include categories where we have at least 10 venues, with a total of at least 20 next venues.

# %%
results_columns = ['# of Venues', '# of Venues With Next',
                   'Total # of Next Venues']
for i in range(1, NRPC + 1):
    results_columns += ['Next Category #' + str(i), 'Pct. #' + str(i)]
results_df = pd.DataFrame(columns=results_columns)

for category, group in venues.groupby('category'):
    num_venues = len(group)
    num_with_next = len(group[group['num next'] > 0])
    if num_with_next < 10:
        continue
    total_next = group['num next'].sum()
    if total_next < 20:
        continue
    results_df.loc[category, '# of Venues'] = num_venues
    results_df.loc[category, '# of Venues With Next'] = num_with_next
    results_df.loc[category, 'Total # of Next Venues'] = total_next
    group_scores = pd.concat(
        [group['next' + str(i + 1)].value_counts()*(WFFR - i)
         for i in range(MNPV)],
        axis=1, sort=False).sum(axis=1)
    group_percent = group_scores*100/group_scores.sum()
    group_percent.sort_values(ascending=False, inplace=True)
    leaders = group_percent.head(NRPC).reset_index()  
    for j in leaders.index:
        results_df.loc[category,
                       'Next Category #' + str(j + 1)
                      ] = leaders.loc[j, 'index']
        results_df.loc[category,
                       'Pct. #' + str(j + 1)
                      ] = leaders.loc[j, 0]        
    
print(results_df.shape)
results_df
# Out:
# (122, 13)
#                               # of Venues # of Venues With Next  \
# Accessories Store                      24                    12
# American Restaurant                   158                   102
# Art Gallery                            83                    42
# Art Museum                             19                    13
# Arts & Crafts Store                    34                    17
# Asian Restaurant                       87                    42
# BBQ Joint                              39                    18
# Bakery                                162                    80
# Bank                                   78                    57
# Bar                                   109                    91
# Big Box Store                          16                    15
# Bookstore                              37                    21
# Boutique                               47                    28
# Breakfast Spot                         62                    42
# Brewery                                19                    18
# Bubble Tea Shop                        30                    19
# Burger Joint                          189                    78
# Café                                  185                    98
# Cajun / Creole Restaurant              14                    10
# Candy Store                            15                    10
# Chinese Restaurant                    183                    91
# Clothing Store                        131                    75
# Cocktail Bar                           49                    42
# Coffee Shop                           387                   243
# Comedy Club                            14                    10
# Concert Hall                           14                    11
# Convenience Store                     197                    69
# Cosmetics Shop                         80                    29
# Deli / Bodega                          49                    18
# Department Store                       42                    23
# Dessert Shop                           55                    34
# Diner                                  50                    36
# Discount Store                         49                    28
# Dive Bar                               20                    15
# Donut Shop                             98                    20
# Farmers Market                         25                    16
# Fast Food Restaurant                  264                   127
# Food Court                             21                    17
# Food Truck                            147                    30
# French Restaurant                      36                    29
# Fried Chicken Joint                    80                    20
# Furniture / Home Store                 71                    26
# Garden                                 18                    14
# Gas Station                            42                    15
# Gastropub                              21                    17
# General Entertainment                  17                    17
# Gift Shop                              44                    28
# Golf Course                            19                    12
# Grocery Store                         174                   108
# Gym                                    80                    31
# Gym / Fitness Center                   89                    36
# Hardware Store                         22                    14
# Hawaiian Restaurant                    13                    10
# Historic Site                          20                    13
# History Museum                         16                    13
# Hotel                                 102                    66
# Hotel Bar                              12                    11
# Ice Cream Shop                         97                    43
# Indian Restaurant                      32                    23
# Italian Restaurant                    111                    73
# Japanese Restaurant                    89                    56
# Juice Bar                              73                    37
# Korean Restaurant                     151                    87
# Latin American Restaurant              48                    15
# Light Rail Station                     23                    12
# Liquor Store                          121                    10
# Lounge                                 37                    27
# Mediterranean Restaurant               63                    38
# Men's Store                            26                    17
# Mexican Restaurant                    429                   158
# Middle Eastern Restaurant              24                    14
# Movie Theater                          35                    24
# Museum                                 32                    26
# Music Venue                            52                    26
# New American Restaurant                39                    30
# Nightclub                              25                    12
# Noodle House                           20                    13
# Paper / Office Supplies Store          15                    10
# Park                                  187                    75
# Performing Arts Venue                  24                    13
# Pet Store                              54                    26
# Pharmacy                              128                    77
# Pizza Place                           247                    72
# Playground                             30                    11
# Plaza                                  18                    14
# Pool                                   18                    11
# Pub                                    14                    13
# Ramen Restaurant                       22                    18
# Record Shop                            18                    11
# Restaurant                            113                    38
# Salad Place                            18                    13
# Salon / Barbershop                     27                    10
# Sandwich Place                        192                    93
# Scenic Lookout                         27                    17
# Seafood Restaurant                     99                    33
# Shipping Store                         36                    16
# Shoe Store                             53                    25
# Shopping Mall                          36                    23
# Spa                                    68                    17
# Speakeasy                              21                    11
# Sporting Goods Shop                    28                    17
# Sports Bar                             11                    11
# Steakhouse                             28                    27
# Supermarket                            34                    31
# Sushi Restaurant                       86                    63
# Taco Place                            100                    37
# Tea Room                               24                    16
# Thai Restaurant                       109                    53
# Theater                                49                    22
# Theme Park                             27                    26
# Theme Park Ride / Attraction           33                    25
# Thrift / Vintage Store                 39                    24
# Toy / Game Store                       12                    12
# Trail                                 130                    33
# Vegetarian / Vegan Restaurant          51                    29
# Vietnamese Restaurant                  34                    25
# Wine Bar                               29                    17
# Wine Shop                              15                    12
# Wings Joint                            26                    13
# Women's Store                          19                    10
# Yoga Studio                            41                    23
# Zoo Exhibit                            28                    21
#
#                               Total # of Next Venues        Next Category #1  \
# Accessories Store                                 40          Clothing Store
# American Restaurant                              397             Coffee Shop
# Art Gallery                                      130             Art Gallery
# Art Museum                                        58              Art Museum
# Arts & Crafts Store                               64           Shopping Mall
# Asian Restaurant                                 130             Coffee Shop
# BBQ Joint                                         71          Ice Cream Shop
# Bakery                                           271             Coffee Shop
# Bank                                             191           Grocery Store
# Bar                                              392                     Bar
# Big Box Store                                     66           Grocery Store
# Bookstore                                         90             Coffee Shop
# Boutique                                          98          Clothing Store
# Breakfast Spot                                   174             Coffee Shop
# Brewery                                           83                 Brewery
# Bubble Tea Shop                                   59           Shopping Mall
# Burger Joint                                     277             Coffee Shop
# Café                                             362           Shopping Mall
# Cajun / Creole Restaurant                         27                     Bar
# Candy Store                                       40           Shopping Mall
# Chinese Restaurant                               284         Bubble Tea Shop
# Clothing Store                                   321          Clothing Store
# Cocktail Bar                                     170                     Bar
# Coffee Shop                                      925           Shopping Mall
# Comedy Club                                       42                     Bar
# Concert Hall                                      45                     Bar
# Convenience Store                                200    Fast Food Restaurant
# Cosmetics Shop                                    89           Shopping Mall
# Deli / Bodega                                     46             Coffee Shop
# Department Store                                  84           Shopping Mall
# Dessert Shop                                     115         Bubble Tea Shop
# Diner                                            142             Coffee Shop
# Discount Store                                    83           Grocery Store
# Dive Bar                                          62                     Bar
# Donut Shop                                        73           Grocery Store
# Farmers Market                                    68             Coffee Shop
# Fast Food Restaurant                             353           Grocery Store
# Food Court                                        71             Coffee Shop
# Food Truck                                        72              Food Truck
# French Restaurant                                125           Shopping Mall
# Fried Chicken Joint                               55             Coffee Shop
# Furniture / Home Store                            97           Grocery Store
# Garden                                            39                  Garden
# Gas Station                                       30             Coffee Shop
# Gastropub                                         78                     Bar
# General Entertainment                             61             Film Studio
# Gift Shop                                         93               Gift Shop
# Golf Course                                       34             Golf Course
# Grocery Store                                    426           Grocery Store
# Gym                                              103           Grocery Store
# Gym / Fitness Center                             136           Grocery Store
# Hardware Store                                    62           Big Box Store
# Hawaiian Restaurant                               32             Coffee Shop
# Historic Site                                     44      Mexican Restaurant
# History Museum                                    52          History Museum
# Hotel                                            266             Coffee Shop
# Hotel Bar                                         38                   Hotel
# Ice Cream Shop                                   163             Coffee Shop
# Indian Restaurant                                 62             Coffee Shop
# Italian Restaurant                               283          Ice Cream Shop
# Japanese Restaurant                              213             Coffee Shop
# Juice Bar                                        138             Coffee Shop
# Korean Restaurant                                303            Dessert Shop
# Latin American Restaurant                         33          Ice Cream Shop
# Light Rail Station                                24      Basketball Stadium
# Liquor Store                                      25           Grocery Store
# Lounge                                           103                     Bar
# Mediterranean Restaurant                         138                    Café
# Men's Store                                       64          Clothing Store
# Mexican Restaurant                               522             Coffee Shop
# Middle Eastern Restaurant                         54          Shopping Plaza
# Movie Theater                                    105             Coffee Shop
# Museum                                           111                  Museum
# Music Venue                                       95                     Bar
# New American Restaurant                          124             Coffee Shop
# Nightclub                                         41                     Bar
# Noodle House                                      58             Coffee Shop
# Paper / Office Supplies Store                     33             Coffee Shop
# Park                                             221                    Park
# Performing Arts Venue                             45                 Theater
# Pet Store                                         84           Grocery Store
# Pharmacy                                         301           Grocery Store
# Pizza Place                                      219             Coffee Shop
# Playground                                        34                    Park
# Plaza                                             56             Coffee Shop
# Pool                                              34                   Hotel
# Pub                                               58                     Bar
# Ramen Restaurant                                  68          Ice Cream Shop
# Record Shop                                       33             Record Shop
# Restaurant                                       122             Coffee Shop
# Salad Place                                       58             Coffee Shop
# Salon / Barbershop                                28             Coffee Shop
# Sandwich Place                                   247             Coffee Shop
# Scenic Lookout                                    47                   Trail
# Seafood Restaurant                               121             Coffee Shop
# Shipping Store                                    43           Grocery Store
# Shoe Store                                        99          Clothing Store
# Shopping Mall                                    100             Coffee Shop
# Spa                                               33       Korean Restaurant
# Speakeasy                                         41                     Bar
# Sporting Goods Shop                               64           Shopping Mall
# Sports Bar                                        32      Basketball Stadium
# Steakhouse                                        90           Shopping Mall
# Supermarket                                      146                Pharmacy
# Sushi Restaurant                                 229             Coffee Shop
# Taco Place                                       120             Coffee Shop
# Tea Room                                          57                   Plaza
# Thai Restaurant                                  162         Thai Restaurant
# Theater                                           60                 Theater
# Theme Park                                       114              Theme Park
# Theme Park Ride / Attraction                     110              Theme Park
# Thrift / Vintage Store                            94  Thrift / Vintage Store
# Toy / Game Store                                  55          Clothing Store
# Trail                                            107                   Trail
# Vegetarian / Vegan Restaurant                    114          Ice Cream Shop
# Vietnamese Restaurant                             89             Coffee Shop
# Wine Bar                                          71                     Bar
# Wine Shop                                         49           Grocery Store
# Wings Joint                                       36           Movie Theater
# Women's Store                                     35          Clothing Store
# Yoga Studio                                       61           Grocery Store
# Zoo Exhibit                                       88             Zoo Exhibit
#
#                                Pct. #1               Next Category #2  \
# Accessories Store              28.9941            Sporting Goods Shop
# American Restaurant            7.01006                  Shopping Mall
# Art Gallery                    20.0909                            Bar
# Art Museum                     28.9979                    Coffee Shop
# Arts & Crafts Store            12.2411                    Coffee Shop
# Asian Restaurant               12.9061                Bubble Tea Shop
# BBQ Joint                      8.00681                   Dessert Shop
# Bakery                         10.1054                  Shopping Mall
# Bank                           14.5601                    Coffee Shop
# Bar                            19.7806                      Gastropub
# Big Box Store                  16.6667                    Coffee Shop
# Bookstore                      9.10326                  Movie Theater
# Boutique                       15.1775                       Boutique
# Breakfast Spot                 18.8865                  Shopping Mall
# Brewery                        28.7202                            Bar
# Bubble Tea Shop                    9.6              Korean Restaurant
# Burger Joint                   10.2731                  Big Box Store
# Café                           8.34164                    Coffee Shop
# Cajun / Creole Restaurant      19.6507                        Stadium
# Candy Store                    10.3976                 Farmers Market
# Chinese Restaurant             13.7427                       Tea Room
# Clothing Store                 22.9326                  Shopping Mall
# Cocktail Bar                   17.7778                   Cocktail Bar
# Coffee Shop                     7.4623                  Grocery Store
# Comedy Club                    15.8824                           Café
# Concert Hall                      12.5            American Restaurant
# Convenience Store              10.7781                    Supermarket
# Cosmetics Shop                 14.5503                    Coffee Shop
# Deli / Bodega                   22.335                  Shopping Mall
# Department Store               13.3238               Department Store
# Dessert Shop                   7.02479                  Shopping Mall
# Diner                          12.5534                  Shopping Mall
# Discount Store                 27.1449                  Big Box Store
# Dive Bar                       18.3432                       Dive Bar
# Donut Shop                     12.6437                  Shopping Mall
# Farmers Market                 16.9369                  Grocery Store
# Fast Food Restaurant           8.69281                    Coffee Shop
# Food Court                     5.67986                     Theme Park
# Food Truck                     18.6603                    Coffee Shop
# French Restaurant              8.27586                    Coffee Shop
# Fried Chicken Joint            7.98319                  Shopping Mall
# Furniture / Home Store         10.0372         Furniture / Home Store
# Garden                         41.7417                       Tea Room
# Gas Station                    18.4211                    Supermarket
# Gastropub                      21.3946                   Concert Hall
# General Entertainment          12.9159                           Café
# Gift Shop                       8.3871                     Theme Park
# Golf Course                    30.8219                           Park
# Grocery Store                  17.1599                    Supermarket
# Gym                              19.47                    Coffee Shop
# Gym / Fitness Center           17.7046                    Supermarket
# Hardware Store                    15.6                  Grocery Store
# Hawaiian Restaurant            10.4869               Department Store
# Historic Site                  12.6344                         Museum
# History Museum                 21.3457                         Museum
# Hotel                          7.03125                            Bar
# Hotel Bar                      12.3418                            Bar
# Ice Cream Shop                 10.0297                  Grocery Store
# Indian Restaurant               11.194                           Café
# Italian Restaurant             8.85372                    Coffee Shop
# Japanese Restaurant            8.71298                 Ice Cream Shop
# Juice Bar                      14.2105                  Shopping Mall
# Korean Restaurant              16.0806                Bubble Tea Shop
# Latin American Restaurant       19.244                            Bar
# Light Rail Station             13.0045           Fast Food Restaurant
# Liquor Store                   16.3636                      Bookstore
# Lounge                         15.2123       Mediterranean Restaurant
# Mediterranean Restaurant       8.85417                    Coffee Shop
# Men's Store                     20.983                  Shopping Mall
# Mexican Restaurant             6.87372                  Grocery Store
# Middle Eastern Restaurant      10.9865                           Café
# Movie Theater                  6.67447                            Bar
# Museum                         10.4857                 Science Museum
# Music Venue                    9.91217                          Diner
# New American Restaurant        7.02275                  Shopping Mall
# Nightclub                      13.8643                          Diner
# Noodle House                   14.0127                 Ice Cream Shop
# Paper / Office Supplies Store   16.726  Paper / Office Supplies Store
# Park                            7.1047                          Trail
# Performing Arts Venue          6.36605            American Restaurant
# Pet Store                      21.0894                    Supermarket
# Pharmacy                       20.0081                    Coffee Shop
# Pizza Place                    8.78415                 Ice Cream Shop
# Playground                     15.7534                  Historic Site
# Plaza                          9.82533             Chinese Restaurant
# Pool                           15.6997                            Bar
# Pub                            14.6497                            Pub
# Ramen Restaurant               13.2143                         Bakery
# Record Shop                    21.6312                    Coffee Shop
# Restaurant                     8.78378                         Bakery
# Salad Place                    16.4179                  Grocery Store
# Salon / Barbershop             14.7059                  Shopping Mall
# Sandwich Place                  20.252                  Grocery Store
# Scenic Lookout                 18.9055                           Park
# Seafood Restaurant                10.9                 Ice Cream Shop
# Shipping Store                 19.6185                    Coffee Shop
# Shoe Store                     19.8032                     Shoe Store
# Shopping Mall                  8.72236               Department Store
# Spa                            14.0468                  Shopping Mall
# Speakeasy                      23.6152              Korean Restaurant
# Sporting Goods Shop            13.2075                 Clothing Store
# Sports Bar                     14.5455               Baseball Stadium
# Steakhouse                     7.29443             Basketball Stadium
# Supermarket                    11.5548                  Grocery Store
# Sushi Restaurant               8.86674                 Ice Cream Shop
# Taco Place                     9.76096                            Bar
# Tea Room                        9.2437                  Shopping Mall
# Thai Restaurant                9.97815                    Coffee Shop
# Theater                        19.4932                            Bar
# Theme Park                     46.4363   Theme Park Ride / Attraction
# Theme Park Ride / Attraction   40.6459   Theme Park Ride / Attraction
# Thrift / Vintage Store         31.0968                 Clothing Store
# Toy / Game Store               7.88288                  Movie Theater
# Trail                          31.5265                           Park
# Vegetarian / Vegan Restaurant  10.6724                  Grocery Store
# Vietnamese Restaurant          9.29919                Bubble Tea Shop
# Wine Bar                       13.8937             Italian Restaurant
# Wine Shop                      28.6783            American Restaurant
# Wings Joint                    17.1521                  Shopping Mall
# Women's Store                   32.526                       Boutique
# Yoga Studio                    31.1909                    Coffee Shop
# Zoo Exhibit                    75.4483                            Zoo
#
#                                Pct. #2               Next Category #3  \
# Accessories Store              11.8343                    Coffee Shop
# American Restaurant            6.40049                            Bar
# Art Gallery                    5.90909                     Art Museum
# Art Museum                     11.7271               Sculpture Garden
# Arts & Crafts Store            6.96798                  Big Box Store
# Asian Restaurant               8.12274                  Grocery Store
# BBQ Joint                      7.15503                    Coffee Shop
# Bakery                         7.16169                  Grocery Store
# Bank                           13.8166                    Supermarket
# Bar                            4.51411                   Cocktail Bar
# Big Box Store                  15.1685                  Shopping Mall
# Bookstore                      5.43478                    Record Shop
# Boutique                       9.30233                    Coffee Shop
# Breakfast Spot                 8.87949                  Grocery Store
# Brewery                        12.2024                   Cocktail Bar
# Bubble Tea Shop                    9.2                         Bakery
# Burger Joint                   7.71565                  Movie Theater
# Café                            7.6105                  Grocery Store
# Cajun / Creole Restaurant      8.73362                 Ice Cream Shop
# Candy Store                     8.8685   Theme Park Ride / Attraction
# Chinese Restaurant             8.93901                  Grocery Store
# Clothing Store                 6.39357               Department Store
# Cocktail Bar                   7.24014            American Restaurant
# Coffee Shop                    7.01639                  Big Box Store
# Comedy Club                         10                    Comedy Club
# Concert Hall                      6.25                    Coffee Shop
# Convenience Store              7.43516                  Grocery Store
# Cosmetics Shop                 10.0529                 Clothing Store
# Deli / Bodega                  6.34518                  Grocery Store
# Department Store               11.4613                  Grocery Store
# Dessert Shop                   6.71488              Korean Restaurant
# Diner                          7.94193                  Big Box Store
# Discount Store                 12.7989                       Pharmacy
# Dive Bar                       8.28402                      Gastropub
# Donut Shop                     10.8374                     Theme Park
# Farmers Market                 9.18919                         Bakery
# Fast Food Restaurant           7.81046                       Pharmacy
# Food Court                     4.81928                 Science Museum
# Food Truck                     10.6858                     Art Museum
# French Restaurant              5.71429                            Bar
# Fried Chicken Joint            6.93277                 Ice Cream Shop
# Furniture / Home Store         9.66543                  Shopping Mall
# Garden                         13.5135                         Museum
# Gas Station                    14.2857                  Grocery Store
# Gastropub                      4.75436                   Cocktail Bar
# General Entertainment          8.21918                         Museum
# Gift Shop                      7.48387                    Coffee Shop
# Golf Course                    9.58904            American Restaurant
# Grocery Store                  9.84633                    Coffee Shop
# Gym                             7.8341                  Shopping Mall
# Gym / Fitness Center           8.62989                    Coffee Shop
# Hardware Store                      12                Warehouse Store
# Hawaiian Restaurant            7.49064                      Bookstore
# Historic Site                  8.33333                  Historic Site
# History Museum                 19.2575                           Park
# Hotel                          6.34191            American Restaurant
# Hotel Bar                      10.7595             Basketball Stadium
# Ice Cream Shop                 6.09212                    Supermarket
# Indian Restaurant              10.2612                         Bakery
# Italian Restaurant             6.88623                  Shopping Mall
# Japanese Restaurant            7.97267                         Bakery
# Juice Bar                      6.92982                  Grocery Store
# Korean Restaurant              12.2481                 Ice Cream Shop
# Latin American Restaurant      13.0584             Mexican Restaurant
# Light Rail Station             8.96861        State / Provincial Park
# Liquor Store                   8.63636                            Bar
# Lounge                         8.72642                      Nightclub
# Mediterranean Restaurant       8.42014                  Shopping Mall
# Men's Store                    9.07372                     Shoe Store
# Mexican Restaurant             4.79562                  Shopping Mall
# Middle Eastern Restaurant      6.27803                         Bakery
# Movie Theater                  5.03513                    Film Studio
# Museum                         7.17439                           Café
# Music Venue                    6.14806                        Theater
# New American Restaurant        6.23145                            Bar
# Nightclub                      13.2743       Mediterranean Restaurant
# Noodle House                   12.5265                Bubble Tea Shop
# Paper / Office Supplies Store   13.879                  Grocery Store
# Park                           5.82265                  Grocery Store
# Performing Arts Venue           6.1008                   Burger Joint
# Pet Store                      6.98324                  Shopping Mall
# Pharmacy                       10.4267           Fast Food Restaurant
# Pizza Place                     7.0166                            Bar
# Playground                     8.90411                    Zoo Exhibit
# Plaza                          8.51528              Korean Restaurant
# Pool                           8.53242             Mexican Restaurant
# Pub                            9.76645                      Gastropub
# Ramen Restaurant               11.7857                    Coffee Shop
# Record Shop                    8.86525                     Donut Shop
# Restaurant                     5.98456                            Bar
# Salad Place                    7.67591          Performing Arts Venue
# Salon / Barbershop             14.2857                    Supermarket
# Sandwich Place                 7.09286                  Shopping Mall
# Scenic Lookout                 16.1692                 Scenic Lookout
# Seafood Restaurant                 8.3                  Shopping Mall
# Shipping Store                  19.346                    Supermarket
# Shoe Store                      9.5941            Sporting Goods Shop
# Shopping Mall                  6.87961             Mexican Restaurant
# Spa                             9.0301  Vegetarian / Vegan Restaurant
# Speakeasy                      6.99708              French Restaurant
# Sporting Goods Shop             9.0566                    Coffee Shop
# Sports Bar                     7.27273         College Football Field
# Steakhouse                     5.30504          General Entertainment
# Supermarket                    10.2804                    Coffee Shop
# Sushi Restaurant                6.7681                         Bakery
# Taco Place                      6.3745               Baseball Stadium
# Tea Room                       8.61345             Chinese Restaurant
# Thai Restaurant                9.90532                 Ice Cream Shop
# Theater                        15.2047                          Plaza
# Theme Park                     44.6004            American Restaurant
# Theme Park Ride / Attraction    39.755                         Museum
# Thrift / Vintage Store         7.35484                  Big Box Store
# Toy / Game Store               7.43243                      Bookstore
# Trail                          18.3628                    Observatory
# Vegetarian / Vegan Restaurant  8.53789                    Coffee Shop
# Vietnamese Restaurant          9.16442                         Bakery
# Wine Bar                       6.17496                    Coffee Shop
# Wine Shop                      7.23192                  Big Box Store
# Wings Joint                    8.73786                  Grocery Store
# Women's Store                  13.8408               Department Store
# Yoga Studio                    19.0926                      Juice Bar
# Zoo Exhibit                     14.069   Theme Park Ride / Attraction
#
#                                Pct. #3              Next Category #4  Pct. #4  \
# Accessories Store              7.10059                   Men's Store  5.02959
# American Restaurant            5.02895                 Grocery Store   4.8156
# Art Gallery                    5.81818                     Gastropub  3.09091
# Art Museum                     7.46269                 Historic Site  7.03625
# Arts & Crafts Store            6.59134                     Bookstore  5.08475
# Asian Restaurant               6.31769                  Dessert Shop  6.22744
# BBQ Joint                      5.96252                          Café  5.62181
# Bakery                         6.72232                        Bakery  4.56942
# Bank                           9.60347                      Pharmacy  9.23172
# Bar                            3.94984                        Lounge  3.44828
# Big Box Store                  8.42697                      Pharmacy  5.61798
# Bookstore                      5.02717                     Bookstore   4.8913
# Boutique                       7.83354                    Shoe Store  6.48715
# Breakfast Spot                 7.32911                   Observatory  3.94644
# Brewery                        5.95238             German Restaurant   4.6131
# Bubble Tea Shop                    7.8                    Shoe Store      7.2
# Burger Joint                    5.3316                 Grocery Store  5.07152
# Café                           4.65271                        Bakery   3.9548
# Cajun / Creole Restaurant      4.36681                     Gastropub  4.36681
# Candy Store                    7.64526                 Movie Theater  5.50459
# Chinese Restaurant              5.9315                   Coffee Shop  5.38847
# Clothing Store                 5.62787                   Coffee Shop  4.82389
# Cocktail Bar                   5.23297                      Dive Bar  4.30108
# Coffee Shop                    4.57705                   Supermarket  3.18689
# Comedy Club                    9.70588           American Restaurant  9.41176
# Concert Hall                   5.97826            Mexican Restaurant  5.97826
# Convenience Store              6.28242                      Pharmacy  5.41787
# Cosmetics Shop                 9.25926                        Bakery  5.29101
# Deli / Bodega                  6.34518                    Art Museum  5.58376
# Department Store               8.73926                Clothing Store  8.45272
# Dessert Shop                   5.57851                          Café  5.06198
# Diner                          6.91716                 Movie Theater  5.63621
# Discount Store                  9.2827                   Supermarket  9.00141
# Dive Bar                       4.93097                 Deli / Bodega  3.94477
# Donut Shop                     8.70279                   Coffee Shop  6.40394
# Farmers Market                 7.20721                     Bookstore  6.12613
# Fast Food Restaurant           6.99346                 Big Box Store  6.86275
# Food Court                     4.47504         General Entertainment  4.47504
# Food Truck                     6.37959                           Bar  6.37959
# French Restaurant              4.82759                    Art Museum  4.82759
# Fried Chicken Joint            6.93277                          Café  5.88235
# Furniture / Home Store         7.68278                 Big Box Store  5.08055
# Garden                         13.5135                          Park  7.20721
# Gas Station                    11.2782                      Pharmacy  7.89474
# Gastropub                      4.12044                      Dive Bar  3.96197
# General Entertainment          6.84932                           Bar  5.28376
# Gift Shop                      5.93548  Theme Park Ride / Attraction  5.16129
# Golf Course                    8.56164                           Bar  6.16438
# Grocery Store                  9.16335                      Pharmacy  8.82186
# Gym                             7.8341                   Supermarket  7.60369
# Gym / Fitness Center           7.11744                     Juice Bar   6.6726
# Hardware Store                    10.4          Fast Food Restaurant      9.4
# Hawaiian Restaurant             7.1161              Video Game Store  6.36704
# Historic Site                  5.10753                 Shopping Mall  5.10753
# History Museum                 10.6729                Science Museum  10.6729
# Hotel                          4.41176                     Hotel Bar  4.22794
# Hotel Bar                      9.49367                  Cocktail Bar  6.96203
# Ice Cream Shop                  5.1263                 Shopping Mall   5.1263
# Indian Restaurant              9.88806                 Shopping Mall  8.39552
# Italian Restaurant              6.0308                           Bar  5.47476
# Japanese Restaurant            6.49203                          Café  5.63781
# Juice Bar                      6.84211                        Bakery   4.5614
# Korean Restaurant              10.5887                   Coffee Shop  9.36389
# Latin American Restaurant      8.59107                        Bakery  6.87285
# Light Rail Station             8.52018                          Park  7.62332
# Liquor Store                   7.27273                Discount Store  4.54545
# Lounge                         5.07075                        Lounge  5.07075
# Mediterranean Restaurant       6.59722                Ice Cream Shop  5.20833
# Men's Store                     7.3724                      Boutique  6.99433
# Mexican Restaurant             4.70427                           Bar  4.61293
# Middle Eastern Restaurant      6.27803                     Multiplex   5.8296
# Movie Theater                  4.68384                Shopping Plaza  4.44965
# Museum                         5.18764                          Park  4.96689
# Music Venue                    5.39523                     Rock Club  4.89335
# New American Restaurant        5.83581                  Cocktail Bar  5.53907
# Nightclub                       7.9646                     Nightclub  7.07965
# Noodle House                   8.28025                  Dessert Shop  6.58174
# Paper / Office Supplies Store  11.7438                   Supermarket   8.8968
# Park                           5.50214                   Coffee Shop  5.34188
# Performing Arts Venue           6.1008  Theme Park Ride / Attraction  5.57029
# Pet Store                      5.02793                 Big Box Store  4.88827
# Pharmacy                       9.82287                   Supermarket   8.9372
# Pizza Place                     6.3203                 Big Box Store  4.65988
# Playground                     7.53425                    Playground  6.50685
# Plaza                          7.42358                        Bakery  7.20524
# Pool                           6.48464                          Park  6.14334
# Pub                            5.52017           American Restaurant  5.52017
# Ramen Restaurant               11.6071               Bubble Tea Shop  8.92857
# Record Shop                     7.0922                     Bookstore  5.67376
# Restaurant                     5.30888                Ice Cream Shop   4.2471
# Salad Place                    7.03625                     Multiplex  5.33049
# Salon / Barbershop              12.605                      Pharmacy  8.40336
# Sandwich Place                 5.55296                   Supermarket  4.66636
# Scenic Lookout                 15.1741                   Observatory  13.4328
# Seafood Restaurant                 6.6                 Movie Theater      4.9
# Shipping Store                 10.6267                 Big Box Store  9.26431
# Shoe Store                     7.50308                   Coffee Shop  6.02706
# Shopping Mall                  5.65111                 Grocery Store  5.28256
# Spa                            6.68896                           Spa  6.02007
# Speakeasy                      4.66472                        Lounge  4.66472
# Sporting Goods Shop            6.22642                 Big Box Store  5.84906
# Sports Bar                     7.27273             Korean Restaurant  6.54545
# Steakhouse                     4.50928                  Concert Hall  4.50928
# Supermarket                    8.07137                        Bakery  6.03229
# Sushi Restaurant               5.40399                           Bar  5.40399
# Taco Place                      5.9761                Ice Cream Shop  5.77689
# Tea Room                       6.51261                 Movie Theater  5.88235
# Thai Restaurant                6.62782                   Supermarket  6.11799
# Theater                        5.84795                   Music Venue  4.67836
# Theme Park                     2.05184                         Diner  1.51188
# Theme Park Ride / Attraction   2.89532         General Entertainment  2.33853
# Thrift / Vintage Store         6.70968                 Shopping Mall  5.41935
# Toy / Game Store               5.63063           Sporting Goods Shop  5.40541
# Trail                          10.3982                Scenic Lookout  10.3982
# Vegetarian / Vegan Restaurant  8.00427                 Shopping Mall  5.65635
# Vietnamese Restaurant          7.54717                Ice Cream Shop  6.60377
# Wine Bar                        5.1458           American Restaurant  4.97427
# Wine Shop                      6.73317                 Shopping Mall  4.48878
# Wings Joint                    8.41424                        Bakery  6.14887
# Women's Store                  8.99654             Electronics Store  4.84429
# Yoga Studio                    6.80529                          Café  6.80529
# Zoo Exhibit                    4.13793                     Gift Shop  1.93103
#
#                                       Next Category #5  Pct. #5
# Accessories Store                          Outlet Mall  5.02959
# American Restaurant                          Multiplex   3.6879
# Art Gallery                                Coffee Shop  3.09091
# Art Museum                     New American Restaurant  7.03625
# Arts & Crafts Store                        Flower Shop  4.89642
# Asian Restaurant                         Big Box Store  6.22744
# BBQ Joint                                Shopping Mall  4.08859
# Bakery                                            Café  4.08612
# Bank                                     Shopping Mall  5.70012
# Bar                                 Mexican Restaurant  3.41693
# Big Box Store                              Supermarket  5.43071
# Bookstore                                Shopping Mall  4.21196
# Boutique                        Thrift / Vintage Store  6.11995
# Breakfast Spot                           Big Box Store  3.38266
# Brewery                                      Gastropub  2.67857
# Bubble Tea Shop                          Grocery Store      6.8
# Burger Joint                             Shopping Mall   4.6814
# Café                                              Café  2.59222
# Cajun / Creole Restaurant                 Liquor Store  4.36681
# Candy Store                                  Bookstore  4.58716
# Chinese Restaurant                        Dessert Shop  4.92899
# Clothing Store                     Sporting Goods Shop  4.51761
# Cocktail Bar                                     Diner  3.65591
# Coffee Shop                                   Pharmacy   2.4918
# Comedy Club                              Deli / Bodega  8.82353
# Concert Hall                                Art Museum   4.8913
# Convenience Store                        Big Box Store  5.24496
# Cosmetics Shop                        Department Store  4.62963
# Deli / Bodega                              Comedy Club  5.07614
# Department Store                         Big Box Store  6.87679
# Dessert Shop                             Big Box Store  4.75207
# Diner                                    Grocery Store  4.78224
# Discount Store                          Discount Store  7.59494
# Dive Bar                                         Diner  3.94477
# Donut Shop                                 Supermarket  3.94089
# Farmers Market                           Shopping Mall   3.6036
# Fast Food Restaurant                     Shopping Mall  6.47059
# Food Court                               Movie Theater  3.95869
# Food Truck                          Seafood Restaurant  4.30622
# French Restaurant                  American Restaurant  4.03941
# Fried Chicken Joint                        Supermarket  5.67227
# Furniture / Home Store                     Coffee Shop   4.7088
# Garden                                   Grocery Store  5.70571
# Gas Station                              Shopping Mall   7.5188
# Gastropub                            French Restaurant  3.96197
# General Entertainment                   Shopping Plaza  5.08806
# Gift Shop                                         Café  4.90323
# Golf Course                          Korean Restaurant  5.13699
# Grocery Store                            Big Box Store  6.63062
# Gym                                          Juice Bar  5.06912
# Gym / Fitness Center                     Shopping Mall  5.51601
# Hardware Store                             Supermarket      8.4
# Hawaiian Restaurant                      Big Box Store  5.24345
# Historic Site                         Pedestrian Plaza  5.10753
# History Museum                           Historic Site  4.87239
# Hotel                                    Shopping Mall  4.18199
# Hotel Bar                          American Restaurant  6.01266
# Ice Cream Shop                               Bookstore  4.90342
# Indian Restaurant                        Big Box Store  6.34328
# Italian Restaurant                       Movie Theater  5.04705
# Japanese Restaurant                                Bar  5.58087
# Juice Bar                                  Supermarket  4.12281
# Korean Restaurant                    Korean Restaurant  7.70446
# Latin American Restaurant            Korean Restaurant  6.52921
# Light Rail Station                       Shopping Mall  7.62332
# Liquor Store                             Movie Theater  4.54545
# Lounge                             American Restaurant  4.48113
# Mediterranean Restaurant                           Bar  3.55903
# Men's Store                                Coffee Shop  6.80529
# Mexican Restaurant                       Movie Theater  3.19708
# Middle Eastern Restaurant                Grocery Store  4.93274
# Movie Theater                      American Restaurant  3.86417
# Museum                           General Entertainment  4.96689
# Music Venue                                Music Venue  4.14053
# New American Restaurant                     Art Museum  4.84669
# Nightclub                                       Lounge  7.07965
# Noodle House                                       Bar  6.36943
# Paper / Office Supplies Store                 Pharmacy  8.54093
# Park                                       Supermarket  4.64744
# Performing Arts Venue                    Historic Site  4.50928
# Pet Store                                  Coffee Shop  4.60894
# Pharmacy                                 Big Box Store  6.80354
# Pizza Place                              Grocery Store   4.4992
# Playground                          Mexican Restaurant  5.82192
# Plaza                               Mexican Restaurant  6.33188
# Pool                                               Gym  5.80205
# Pub                                        Coffee Shop  5.09554
# Ramen Restaurant                                   Bar     8.75
# Record Shop                               Burger Joint  5.31915
# Restaurant                               Grocery Store  4.05405
# Salad Place                              Shopping Mall  5.11727
# Salon / Barbershop                              Bakery  7.56303
# Sandwich Place                       Convenience Store  3.91974
# Scenic Lookout                                Mountain  4.47761
# Seafood Restaurant                        Dessert Shop      4.3
# Shipping Store                    Fast Food Restaurant  5.44959
# Shoe Store                                 Outlet Mall  4.55105
# Shopping Mall                                   Bakery   4.6683
# Spa                                     Shopping Plaza  6.02007
# Speakeasy                                   Whisky Bar  4.66472
# Sporting Goods Shop                        Outlet Mall  5.28302
# Sports Bar                                   Rock Club  5.45455
# Steakhouse                                   Multiplex  3.97878
# Supermarket                                Supermarket  5.86236
# Sushi Restaurant                         Grocery Store  4.35467
# Taco Place                               Shopping Mall  4.98008
# Tea Room                                 Big Box Store   5.2521
# Thai Restaurant                              Multiplex  5.82666
# Theater                                    Coffee Shop  3.89864
# Theme Park                               Historic Site  1.07991
# Theme Park Ride / Attraction                       Zoo  2.22717
# Thrift / Vintage Store                   Grocery Store  5.16129
# Toy / Game Store                        Shopping Plaza  4.05405
# Trail                                         Mountain  4.42478
# Vegetarian / Vegan Restaurant            Movie Theater  4.48239
# Vietnamese Restaurant                    Grocery Store  5.92992
# Wine Bar                                  Cocktail Bar  4.28816
# Wine Shop                                  Coffee Shop   4.2394
# Wings Joint                             Ice Cream Shop  5.50162
# Women's Store                                Bookstore  4.84429
# Yoga Studio                                Supermarket  6.61626
# Zoo Exhibit                       Fast Food Restaurant  1.93103

# %% [markdown]
# Thus, for 122 venue categories, we have recommendations for targeting advertising to people at those venues.
